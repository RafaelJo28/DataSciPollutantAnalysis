# %%
import pandas as pd

# %% [markdown]
# #Moscow Analysis

# %%
Moscow_df = pd.read_csv('/content/Moscow.csv')
print('\nMoscow Data:')
display(Moscow_df.head())
# Out:
# Moscow Data:
#                         date  pm10  pm2_5  carbon_monoxide  carbon_dioxide  \
# 0  2020-01-01 00:00:00+00:00   9.8    7.7            208.0             NaN
# 1  2020-01-01 01:00:00+00:00  13.0    9.6            217.0             NaN
# 2  2020-01-01 02:00:00+00:00  12.1    9.2            205.0             NaN
# 3  2020-01-01 03:00:00+00:00  10.6    7.5            189.0             NaN
# 4  2020-01-01 04:00:00+00:00   9.8    7.0            189.0             NaN
#
#    nitrogen_dioxide  sulphur_dioxide  ozone  ammonia  methane
# 0              26.0             17.8   28.0      0.3      NaN
# 1              30.1             18.8   25.0      0.4      NaN
# 2              29.3             19.1   20.0      0.3      NaN
# 3              21.1             15.6   28.0      0.2      NaN
# 4              19.5             12.8   33.0      0.3      NaN

# %%
Moscow_df
# Out:
#                             date  pm10  pm2_5  carbon_monoxide  \
# 0      2020-01-01 00:00:00+00:00   9.8    7.7            208.0
# 1      2020-01-01 01:00:00+00:00  13.0    9.6            217.0
# 2      2020-01-01 02:00:00+00:00  12.1    9.2            205.0
# 3      2020-01-01 03:00:00+00:00  10.6    7.5            189.0
# 4      2020-01-01 04:00:00+00:00   9.8    7.0            189.0
# ...                          ...   ...    ...              ...
# 43867  2025-01-01 19:00:00+00:00  15.3   13.5            286.0
# 43868  2025-01-01 20:00:00+00:00  15.9   14.2            264.0
# 43869  2025-01-01 21:00:00+00:00  16.5   14.9            238.0
# 43870  2025-01-01 22:00:00+00:00  15.9   14.3            221.0
# 43871  2025-01-01 23:00:00+00:00  16.2   14.9            207.0
#
#        carbon_dioxide  nitrogen_dioxide  sulphur_dioxide  ozone  ammonia  \
# 0                 NaN              26.0             17.8   28.0      0.3
# 1                 NaN              30.1             18.8   25.0      0.4
# 2                 NaN              29.3             19.1   20.0      0.3
# 3                 NaN              21.1             15.6   28.0      0.2
# 4                 NaN              19.5             12.8   33.0      0.3
# ...               ...               ...              ...    ...      ...
# 43867           465.0              24.7             20.8   42.0      0.2
# 43868           461.0              20.0             19.0   42.0      0.2
# 43869           457.0              16.9             13.8   42.0      0.2
# 43870           455.0              15.1             13.3   43.0      0.1
# 43871           454.0              14.5             14.2   45.0      0.1
#
#        methane
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 43867   1540.0
# 43868   1531.0
# 43869   1524.0
# 43870   1523.0
# 43871   1524.0
#
# [43872 rows x 10 columns]

# %% [markdown]
# #Paris Analysis

# %%
Paris_df = pd.read_csv('/content/Paris.csv')
print('\nParis Data:')
display(Paris_df.head())
# Out:
# Paris Data:
#                         date  pm10  pm2_5  carbon_monoxide  carbon_dioxide  \
# 0  2020-01-01 00:00:00+00:00  64.3   39.4            571.0             NaN
# 1  2020-01-01 01:00:00+00:00  64.2   44.7            468.0             NaN
# 2  2020-01-01 02:00:00+00:00  65.6   48.6            501.0             NaN
# 3  2020-01-01 03:00:00+00:00  52.7   41.9            434.0             NaN
# 4  2020-01-01 04:00:00+00:00  30.2   26.6            378.0             NaN
#
#    nitrogen_dioxide  sulphur_dioxide  ozone  ammonia  methane
# 0              42.8              8.1    0.0      1.4      NaN
# 1              38.7              3.1    0.0      1.7      NaN
# 2              33.2              2.7    3.0      1.3      NaN
# 3              31.0              2.1    2.0      0.9      NaN
# 4              30.6              2.0    3.0      0.7      NaN

# %%
Paris_df
# Out:
#                             date  pm10  pm2_5  carbon_monoxide  \
# 0      2020-01-01 00:00:00+00:00  64.3   39.4            571.0
# 1      2020-01-01 01:00:00+00:00  64.2   44.7            468.0
# 2      2020-01-01 02:00:00+00:00  65.6   48.6            501.0
# 3      2020-01-01 03:00:00+00:00  52.7   41.9            434.0
# 4      2020-01-01 04:00:00+00:00  30.2   26.6            378.0
# ...                          ...   ...    ...              ...
# 43867  2025-01-01 19:00:00+00:00  14.5    9.9            193.0
# 43868  2025-01-01 20:00:00+00:00  14.3    9.8            191.0
# 43869  2025-01-01 21:00:00+00:00  14.3    9.7            183.0
# 43870  2025-01-01 22:00:00+00:00  12.8    9.3            176.0
# 43871  2025-01-01 23:00:00+00:00  10.8    8.1            165.0
#
#        carbon_dioxide  nitrogen_dioxide  sulphur_dioxide  ozone  ammonia  \
# 0                 NaN              42.8              8.1    0.0      1.4
# 1                 NaN              38.7              3.1    0.0      1.7
# 2                 NaN              33.2              2.7    3.0      1.3
# 3                 NaN              31.0              2.1    2.0      0.9
# 4                 NaN              30.6              2.0    3.0      0.7
# ...               ...               ...              ...    ...      ...
# 43867           453.0              19.4              2.0   51.0      0.6
# 43868           453.0              15.9              1.8   55.0      0.6
# 43869           453.0              13.2              1.7   58.0      0.5
# 43870           452.0              10.6              1.2   58.0      0.4
# 43871           451.0               7.0              1.0   60.0      0.4
#
#        methane
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 43867   1413.0
# 43868   1413.0
# 43869   1413.0
# 43870   1413.0
# 43871   1414.0
#
# [43872 rows x 10 columns]

# %% [markdown]
# #London Analysis

# %%
London_df = pd.read_csv('/content/London.csv')
print('\nLondon Data:')
display(London_df.head())
# Out:
# London Data:
#                         date  pm10  pm2_5  carbon_monoxide  carbon_dioxide  \
# 0  2020-01-01 00:00:00+00:00  42.1   32.8            339.0             NaN
# 1  2020-01-01 01:00:00+00:00  44.1   36.1            399.0             NaN
# 2  2020-01-01 02:00:00+00:00  41.6   38.7            422.0             NaN
# 3  2020-01-01 03:00:00+00:00  47.3   42.7            420.0             NaN
# 4  2020-01-01 04:00:00+00:00  50.9   44.8            367.0             NaN
#
#    nitrogen_dioxide  sulphur_dioxide  ozone  ammonia  methane
# 0              43.4              4.3    1.0      1.6      NaN
# 1              42.4              4.3    1.0      2.8      NaN
# 2              42.6              4.8    2.0      2.4      NaN
# 3              40.8              4.5    2.0      1.7      NaN
# 4              39.4              4.7    2.0      0.7      NaN

# %%
London_df
# Out:
#                             date  pm10  pm2_5  carbon_monoxide  \
# 0      2020-01-01 00:00:00+00:00  42.1   32.8            339.0
# 1      2020-01-01 01:00:00+00:00  44.1   36.1            399.0
# 2      2020-01-01 02:00:00+00:00  41.6   38.7            422.0
# 3      2020-01-01 03:00:00+00:00  47.3   42.7            420.0
# 4      2020-01-01 04:00:00+00:00  50.9   44.8            367.0
# ...                          ...   ...    ...              ...
# 43867  2025-01-01 19:00:00+00:00   7.2    5.8            194.0
# 43868  2025-01-01 20:00:00+00:00   8.5    6.3            189.0
# 43869  2025-01-01 21:00:00+00:00   9.6    6.8            183.0
# 43870  2025-01-01 22:00:00+00:00  10.9    7.9            187.0
# 43871  2025-01-01 23:00:00+00:00  11.8    9.4            203.0
#
#        carbon_dioxide  nitrogen_dioxide  sulphur_dioxide  ozone  ammonia  \
# 0                 NaN              43.4              4.3    1.0      1.6
# 1                 NaN              42.4              4.3    1.0      2.8
# 2                 NaN              42.6              4.8    2.0      2.4
# 3                 NaN              40.8              4.5    2.0      1.7
# 4                 NaN              39.4              4.7    2.0      0.7
# ...               ...               ...              ...    ...      ...
# 43867           456.0              34.4              2.9   41.0      1.3
# 43868           459.0              30.6              3.2   43.0      1.1
# 43869           462.0              32.0              3.5   46.0      1.3
# 43870           464.0              34.8              4.1   35.0      1.5
# 43871           466.0              43.8              5.8   29.0      2.3
#
#        methane
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 43867   1386.0
# 43868   1390.0
# 43869   1397.0
# 43870   1409.0
# 43871   1423.0
#
# [43872 rows x 10 columns]

# %% [markdown]
# #Madrid Analysis

# %%
Madrid_df = pd.read_csv('/content/Madrid.csv')
print('\nMadrid Data:')
display(Madrid_df.head())
# Out:
# Madrid Data:
#                         date  pm10  pm2_5  carbon_monoxide  carbon_dioxide  \
# 0  2020-01-01 00:00:00+00:00  44.3   32.8            438.0             NaN
# 1  2020-01-01 01:00:00+00:00  46.2   32.8            375.0             NaN
# 2  2020-01-01 02:00:00+00:00  47.6   33.8            430.0             NaN
# 3  2020-01-01 03:00:00+00:00  50.4   35.3            398.0             NaN
# 4  2020-01-01 04:00:00+00:00  44.8   34.6            335.0             NaN
#
#    nitrogen_dioxide  sulphur_dioxide  ozone  ammonia  methane
# 0              60.7             11.7    0.0      1.7      NaN
# 1              55.1             12.0    0.0      0.8      NaN
# 2              53.5             11.7    0.0      0.7      NaN
# 3              52.8             11.6    1.0      0.4      NaN
# 4              50.5             10.0    1.0      0.5      NaN

# %%
Madrid_df
# Out:
#                             date  pm10  pm2_5  carbon_monoxide  \
# 0      2020-01-01 00:00:00+00:00  44.3   32.8            438.0
# 1      2020-01-01 01:00:00+00:00  46.2   32.8            375.0
# 2      2020-01-01 02:00:00+00:00  47.6   33.8            430.0
# 3      2020-01-01 03:00:00+00:00  50.4   35.3            398.0
# 4      2020-01-01 04:00:00+00:00  44.8   34.6            335.0
# ...                          ...   ...    ...              ...
# 43867  2025-01-01 19:00:00+00:00  46.1   30.7            381.0
# 43868  2025-01-01 20:00:00+00:00  39.2   35.1            301.0
# 43869  2025-01-01 21:00:00+00:00  36.3   34.6            267.0
# 43870  2025-01-01 22:00:00+00:00  37.6   33.9            268.0
# 43871  2025-01-01 23:00:00+00:00  37.0   35.3            277.0
#
#        carbon_dioxide  nitrogen_dioxide  sulphur_dioxide  ozone  ammonia  \
# 0                 NaN              60.7             11.7    0.0      1.7
# 1                 NaN              55.1             12.0    0.0      0.8
# 2                 NaN              53.5             11.7    0.0      0.7
# 3                 NaN              52.8             11.6    1.0      0.4
# 4                 NaN              50.5             10.0    1.0      0.5
# ...               ...               ...              ...    ...      ...
# 43867           559.0              81.2             38.1    1.0      1.8
# 43868           571.0              75.5             20.3    1.0      1.4
# 43869           575.0              62.1             15.9    3.0      1.1
# 43870           567.0              54.0             20.6    2.0      0.8
# 43871           552.0              52.2             15.3    1.0      0.7
#
#        methane
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 43867   1590.0
# 43868   1544.0
# 43869   1514.0
# 43870   1523.0
# 43871   1547.0
#
# [43872 rows x 10 columns]

# %% [markdown]
# #Barcelona Analysis

# %%
Barcelona_df = pd.read_csv('/content/Barcelona.csv')
print('\nBarcelona Data:')
display(Barcelona_df.head())
# Out:
# Barcelona Data:
#                         date  pm10  pm2_5  carbon_monoxide  carbon_dioxide  \
# 0  2020-01-01 00:00:00+00:00  21.1   23.5            263.0             NaN
# 1  2020-01-01 01:00:00+00:00  22.8   21.0            251.0             NaN
# 2  2020-01-01 02:00:00+00:00  23.6   24.0            240.0             NaN
# 3  2020-01-01 03:00:00+00:00  21.8   19.8            227.0             NaN
# 4  2020-01-01 04:00:00+00:00  21.0   16.3            228.0             NaN
#
#    nitrogen_dioxide  sulphur_dioxide  ozone  ammonia  methane
# 0              21.3              3.0   16.0      3.1      NaN
# 1              31.9              3.0   11.0      2.7      NaN
# 2              33.1              3.2   14.0      2.5      NaN
# 3              26.8              1.9   15.0      2.4      NaN
# 4              29.6              2.5    9.0      2.9      NaN

# %%
Barcelona_df
# Out:
#                             date  pm10  pm2_5  carbon_monoxide  \
# 0      2020-01-01 00:00:00+00:00  21.1   23.5            263.0
# 1      2020-01-01 01:00:00+00:00  22.8   21.0            251.0
# 2      2020-01-01 02:00:00+00:00  23.6   24.0            240.0
# 3      2020-01-01 03:00:00+00:00  21.8   19.8            227.0
# 4      2020-01-01 04:00:00+00:00  21.0   16.3            228.0
# ...                          ...   ...    ...              ...
# 43867  2025-01-01 19:00:00+00:00  41.1   31.4            367.0
# 43868  2025-01-01 20:00:00+00:00  49.8   36.2            383.0
# 43869  2025-01-01 21:00:00+00:00  54.6   42.5            421.0
# 43870  2025-01-01 22:00:00+00:00  48.6   45.9            373.0
# 43871  2025-01-01 23:00:00+00:00  45.3   42.8            309.0
#
#        carbon_dioxide  nitrogen_dioxide  sulphur_dioxide  ozone  ammonia  \
# 0                 NaN              21.3              3.0   16.0      3.1
# 1                 NaN              31.9              3.0   11.0      2.7
# 2                 NaN              33.1              3.2   14.0      2.5
# 3                 NaN              26.8              1.9   15.0      2.4
# 4                 NaN              29.6              2.5    9.0      2.9
# ...               ...               ...              ...    ...      ...
# 43867           505.0              97.7             30.9    4.0      6.6
# 43868           517.0             101.7             37.2    4.0      6.7
# 43869           521.0              86.1             26.9    2.0      7.6
# 43870           512.0              72.6             15.8    2.0      5.8
# 43871           496.0              55.4             11.5    7.0      5.9
#
#        methane
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 43867   1648.0
# 43868   1709.0
# 43869   1744.0
# 43870   1730.0
# 43871   1690.0
#
# [43872 rows x 10 columns]

# %% [markdown]
# #Moscow Cleaning

# %%
import pandas as pd
import numpy as np

fn = "Moscow.csv"
df = pd.read_csv(fn)

print("shape:", df.shape)
print("columns:", df.columns.tolist())
print(df.head(5))
print("\nmissing per column:\n", df.isna().sum())
# Out:
# shape: (43872, 10)
# columns: ['date', 'pm10', 'pm2_5', 'carbon_monoxide', 'carbon_dioxide', 'nitrogen_dioxide', 'sulphur_dioxide', 'ozone', 'ammonia', 'methane']
#                         date  pm10  pm2_5  carbon_monoxide  carbon_dioxide  \
# 0  2020-01-01 00:00:00+00:00   9.8    7.7            208.0             NaN
# 1  2020-01-01 01:00:00+00:00  13.0    9.6            217.0             NaN
# 2  2020-01-01 02:00:00+00:00  12.1    9.2            205.0             NaN
# 3  2020-01-01 03:00:00+00:00  10.6    7.5            189.0             NaN
# 4  2020-01-01 04:00:00+00:00   9.8    7.0            189.0             NaN
#
#    nitrogen_dioxide  sulphur_dioxide  ozone  ammonia  methane
# 0              26.0             17.8   28.0      0.3      NaN
# 1              30.1             18.8   25.0      0.4      NaN
# 2              29.3             19.1   20.0      0.3      NaN
# 3              21.1             15.6   28.0      0.2      NaN
# 4              19.5             12.8   33.0      0.3      NaN
#
# missing per column:
#  date                    0
# pm10                    0
# pm2_5                   0
# carbon_monoxide         0
# carbon_dioxide      42240
# nitrogen_dioxide        0
# sulphur_dioxide         0
# ozone                   0
# ammonia                 0
# methane             42240
# dtype: int64

# %%
df.columns = (
    df.columns.str.strip()
              .str.lower()
              .str.replace(" ", "_")
              .str.replace("-", "_")
)

print(df.columns.tolist())
# Out:
# ['date', 'pm10', 'pm2_5', 'carbon_monoxide', 'carbon_dioxide', 'nitrogen_dioxide', 'sulphur_dioxide', 'ozone', 'ammonia', 'methane']

# %%
candidates = ["datetime", "date_time", "date", "time", "timestamp"]
dt_col = None

for c in candidates:
    if c in df.columns:
        dt_col = c
        break

if dt_col is None:
    raise RuntimeError("No datetime column found. Rename your column to one of: " + ", ".join(candidates))

df["datetime"] = pd.to_datetime(df[dt_col], errors="coerce")
print("Parsed datetime:", dt_col, " — nulls:", df["datetime"].isna().sum())

df = df[~df["datetime"].isna()].copy()
df = df.sort_values("datetime").reset_index(drop=True)

print("After datetime cleaning, rows:", len(df))
# Out:
# Parsed datetime: date  — nulls: 0
# After datetime cleaning, rows: 43872

# %%
pollutants = [
    "pm10","pm2_5","ammonia",
    "carbon_monoxide","nitrogen_dioxide",
    "carbon_dioxide","sulphur_dioxide","methane"
]

# try to fix common alternative column names
col_map = {}
for p in pollutants:
    if p not in df.columns:
        alternatives = [
            p.replace("_",""),
            p.replace("2_5","2.5"),
            p.replace("pm2_5","pm2.5"),
            p.replace("pm2_5","pm25"),
        ]
        for alt in alternatives:
            if alt in df.columns:
                col_map[alt] = p

if col_map:
    df = df.rename(columns=col_map)
    print("Renamed columns:", col_map)

missing = [p for p in pollutants if p not in df.columns]
if missing:
    print("Warning: Missing pollutant columns:", missing)

# convert to numeric
for p in pollutants:
    if p in df.columns:
        df[p] = (
            df[p].astype(str)
                 .str.replace("<","")
                 .str.replace(",","")
                 .str.strip()
        )
        df[p] = pd.to_numeric(df[p], errors="coerce")

# %%
# negative values → NaN
for p in pollutants:
    if p in df.columns:
        df.loc[df[p] < 0, p] = np.nan

# cap at 99.9 percentile (pollutant-dependent)
for p in pollutants:
    if p in df.columns:
        q = df[p].quantile(0.999)
        if pd.notna(q) and q > 0:
            df.loc[df[p] > q, p] = np.nan
        print(f"{p}: capped at {q}")
# Out:
# pm10: capped at 181.1676000000356
# pm2_5: capped at 144.55160000000325
# ammonia: capped at 13.5
# carbon_monoxide: capped at 1839.70900000017
# nitrogen_dioxide: capped at 120.41290000000082
# carbon_dioxide: capped at 953.8780000000088
# sulphur_dioxide: capped at 248.09020000003073
# methane: capped at 4572.686000000013

# %%
df = df.set_index("datetime")

start = df.index.min().ceil("H")
end   = df.index.max().floor("H")

full_idx = pd.date_range(start=start, end=end, freq="H")

df = df.reindex(full_idx)
print("Reindexed to hourly:", len(df))
# Out:
# Reindexed to hourly: 43872
# /tmp/ipython-input-1351569827.py:3: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   start = df.index.min().ceil("H")
# /tmp/ipython-input-1351569827.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   end   = df.index.max().floor("H")
# /tmp/ipython-input-1351569827.py:6: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   full_idx = pd.date_range(start=start, end=end, freq="H")

# %%
numeric_cols = [c for c in pollutants if c in df.columns]

df[numeric_cols] = df[numeric_cols].interpolate(method="time", limit=24)
df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

print("Remaining NaNs:\n", df[numeric_cols].isna().sum())
# Out:
# Remaining NaNs:
#  pm10                    0
# pm2_5                   0
# ammonia                 0
# carbon_monoxide         0
# nitrogen_dioxide        0
# carbon_dioxide      42234
# sulphur_dioxide         0
# methane             42234
# dtype: int64
# /tmp/ipython-input-774743577.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

# %%
df["missing_pollutants"] = df[numeric_cols].isna().sum(axis=1)

summary = df[numeric_cols].describe().T
summary["missing"] = df[numeric_cols].isna().sum()

summary
# Out:
#                     count         mean         std     min     25%     50%  \
# pm10              43872.0    28.788225   19.345099     4.3    16.1    23.6
# pm2_5             43872.0    22.564930   15.351611     3.3    12.5    18.4
# ammonia           43872.0     1.689878    1.541934     0.0     0.7     1.2
# carbon_monoxide   43872.0   344.664256  182.175592   128.0   231.0   292.0
# nitrogen_dioxide  43872.0    36.931041   17.110122     6.2    23.9    34.1
# carbon_dioxide     1638.0   481.507326   45.336194   439.0   459.0   469.0
# sulphur_dioxide   43872.0    32.031728   24.411658     4.0    16.7    25.2
# methane            1638.0  1739.286325  325.389603  1420.0  1560.0  1642.0
#
#                      75%     max  missing
# pm10                35.2   180.6        0
# pm2_5               27.7   144.5        0
# ammonia              2.2    13.5        0
# carbon_monoxide    394.0  1837.0        0
# nitrogen_dioxide    47.0   120.4        0
# carbon_dioxide     488.0   931.0    42234
# sulphur_dioxide     39.0   247.6        0
# methane           1794.0  4538.0    42234

# %%
means = df[numeric_cols].mean(skipna=True)              # may contain NaN for pollutant with no valid data
ranking = means.reset_index()
ranking.columns = ["pollutant", "mean_value"]

# Split valid (finite means) and invalid (NaN means)
valid = ranking[ranking["mean_value"].notna()].copy()
invalid = ranking[ranking["mean_value"].isna()].copy()

# Rank only the valid ones (descending); convert to int safely
valid["rank"] = valid["mean_value"].rank(method="min", ascending=False).astype(int)

# For invalid ones, set rank to pandas NA (nullable Int) or a large number if you prefer
import pandas as pd
invalid["rank"] = pd.NA

# Combine back, put valid ranked items first
final_ranking = pd.concat([valid, invalid], ignore_index=True)
final_ranking = final_ranking.sort_values(by=["rank", "pollutant"], na_position="last").reset_index(drop=True)

print(final_ranking)

# Save cleaned hourly file and ranking
df.reset_index().rename(columns={"index":"datetime"}).to_csv("Moscow_clean_hourly.csv", index=False)
final_ranking.to_csv("Moscow_pollutant_ranking.csv", index=False)

print("Saved: Moscow_clean_hourly.csv and Moscow_pollutant_ranking.csv")
# Out:
#           pollutant   mean_value rank
# 0           methane  1739.286325    1
# 1    carbon_dioxide   481.507326    2
# 2   carbon_monoxide   344.664256    3
# 3  nitrogen_dioxide    36.931041    4
# 4   sulphur_dioxide    32.031728    5
# 5              pm10    28.788225    6
# 6             pm2_5    22.564930    7
# 7           ammonia     1.689878    8
# Saved: Moscow_clean_hourly.csv and Moscow_pollutant_ranking.csv

# %% [markdown]
# #Paris Cleaning

# %%
import pandas as pd
import numpy as np

fn = "Paris.csv"
df = pd.read_csv(fn)

print("shape:", df.shape)
print("columns:", df.columns.tolist())
print(df.head(5))
print("\nmissing per column:\n", df.isna().sum())
# Out:
# shape: (43872, 10)
# columns: ['date', 'pm10', 'pm2_5', 'carbon_monoxide', 'carbon_dioxide', 'nitrogen_dioxide', 'sulphur_dioxide', 'ozone', 'ammonia', 'methane']
#                         date  pm10  pm2_5  carbon_monoxide  carbon_dioxide  \
# 0  2020-01-01 00:00:00+00:00  64.3   39.4            571.0             NaN
# 1  2020-01-01 01:00:00+00:00  64.2   44.7            468.0             NaN
# 2  2020-01-01 02:00:00+00:00  65.6   48.6            501.0             NaN
# 3  2020-01-01 03:00:00+00:00  52.7   41.9            434.0             NaN
# 4  2020-01-01 04:00:00+00:00  30.2   26.6            378.0             NaN
#
#    nitrogen_dioxide  sulphur_dioxide  ozone  ammonia  methane
# 0              42.8              8.1    0.0      1.4      NaN
# 1              38.7              3.1    0.0      1.7      NaN
# 2              33.2              2.7    3.0      1.3      NaN
# 3              31.0              2.1    2.0      0.9      NaN
# 4              30.6              2.0    3.0      0.7      NaN
#
# missing per column:
#  date                    0
# pm10                    0
# pm2_5                   0
# carbon_monoxide         0
# carbon_dioxide      42240
# nitrogen_dioxide        0
# sulphur_dioxide         0
# ozone                   0
# ammonia                 0
# methane             42240
# dtype: int64

# %%
df.columns = (
    df.columns.str.strip()
              .str.lower()
              .str.replace(" ", "_")
              .str.replace("-", "_")
)

print(df.columns.tolist())
# Out:
# ['date', 'pm10', 'pm2_5', 'carbon_monoxide', 'carbon_dioxide', 'nitrogen_dioxide', 'sulphur_dioxide', 'ozone', 'ammonia', 'methane']

# %%
candidates = ["datetime", "date_time", "date", "time", "timestamp"]
dt_col = None

for c in candidates:
    if c in df.columns:
        dt_col = c
        break

if dt_col is None:
    raise RuntimeError("No datetime column found. Rename your column to one of: " + ", ".join(candidates))

df["datetime"] = pd.to_datetime(df[dt_col], errors="coerce")
print("Parsed datetime:", dt_col, " — nulls:", df["datetime"].isna().sum())

df = df[~df["datetime"].isna()].copy()
df = df.sort_values("datetime").reset_index(drop=True)

print("After datetime cleaning, rows:", len(df))
# Out:
# Parsed datetime: date  — nulls: 0
# After datetime cleaning, rows: 43872

# %%
pollutants = [
    "pm10","pm2_5","ammonia",
    "carbon_monoxide","nitrogen_dioxide",
    "carbon_dioxide","sulphur_dioxide","methane"
]

# try to fix common alternative column names
col_map = {}
for p in pollutants:
    if p not in df.columns:
        alternatives = [
            p.replace("_",""),
            p.replace("2_5","2.5"),
            p.replace("pm2_5","pm2.5"),
            p.replace("pm2_5","pm25"),
        ]
        for alt in alternatives:
            if alt in df.columns:
                col_map[alt] = p

if col_map:
    df = df.rename(columns=col_map)
    print("Renamed columns:", col_map)

missing = [p for p in pollutants if p not in df.columns]
if missing:
    print("Warning: Missing pollutant columns:", missing)

# convert to numeric
for p in pollutants:
    if p in df.columns:
        df[p] = (
            df[p].astype(str)
                 .str.replace("<","")
                 .str.replace(",","")
                 .str.strip()
        )
        df[p] = pd.to_numeric(df[p], errors="coerce")

# %%
# negative values → NaN
for p in pollutants:
    if p in df.columns:
        df.loc[df[p] < 0, p] = np.nan

# cap at 99.9 percentile (pollutant-dependent)
for p in pollutants:
    if p in df.columns:
        q = df[p].quantile(0.999)
        if pd.notna(q) and q > 0:
            df.loc[df[p] > q, p] = np.nan
        print(f"{p}: capped at {q}")
# Out:
# pm10: capped at 72.71290000000081
# pm2_5: capped at 56.9
# ammonia: capped at 13.5
# carbon_monoxide: capped at 759.2580000000162
# nitrogen_dioxide: capped at 91.06450000000405
# carbon_dioxide: capped at 868.2140000000009
# sulphur_dioxide: capped at 17.225800000001616
# methane: capped at 3492.535000000002

# %%
df = df.set_index("datetime")

start = df.index.min().ceil("H")
end   = df.index.max().floor("H")

full_idx = pd.date_range(start=start, end=end, freq="H")

df = df.reindex(full_idx)
print("Reindexed to hourly:", len(df))
# Out:
# Reindexed to hourly: 43872
# /tmp/ipython-input-1351569827.py:3: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   start = df.index.min().ceil("H")
# /tmp/ipython-input-1351569827.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   end   = df.index.max().floor("H")
# /tmp/ipython-input-1351569827.py:6: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   full_idx = pd.date_range(start=start, end=end, freq="H")

# %%
numeric_cols = [c for c in pollutants if c in df.columns]

df[numeric_cols] = df[numeric_cols].interpolate(method="time", limit=24)
df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

print("Remaining NaNs:\n", df[numeric_cols].isna().sum())
# Out:
# Remaining NaNs:
#  pm10                    0
# pm2_5                   0
# ammonia                 0
# carbon_monoxide         0
# nitrogen_dioxide        0
# carbon_dioxide      42234
# sulphur_dioxide         0
# methane             42234
# dtype: int64
# /tmp/ipython-input-774743577.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

# %%
df["missing_pollutants"] = df[numeric_cols].isna().sum(axis=1)

summary = df[numeric_cols].describe().T
summary["missing"] = df[numeric_cols].isna().sum()

summary
# Out:
#                     count         mean         std     min     25%     50%  \
# pm10              43872.0    16.667219    9.505985     1.6    10.2    14.3
# pm2_5             43872.0    10.909786    7.470229     1.2     6.0     8.6
# ammonia           43872.0     2.435989    1.867708     0.1     1.1     1.9
# carbon_monoxide   43872.0   204.889913   76.777503    72.0   157.0   186.0
# nitrogen_dioxide  43872.0    23.134675   15.302060     1.8    11.6    18.8
# carbon_dioxide     1638.0   490.637973   62.092084   434.0   455.0   469.5
# sulphur_dioxide   43872.0     2.223148    1.841946     0.2     1.1     1.7
# methane            1638.0  1595.517705  286.483258  1368.0  1421.0  1490.0
#
#                      75%     max  missing
# pm10                20.4    72.7        0
# pm2_5               13.2    56.9        0
# ammonia              3.1    13.5        0
# carbon_monoxide    230.0   759.0        0
# nitrogen_dioxide    30.8    91.0        0
# carbon_dioxide     498.0   866.0    42234
# sulphur_dioxide      2.6    17.2        0
# methane           1661.5  3487.0    42234

# %%
means = df[numeric_cols].mean(skipna=True)              # may contain NaN for pollutant with no valid data
ranking = means.reset_index()
ranking.columns = ["pollutant", "mean_value"]

# Split valid (finite means) and invalid (NaN means)
valid = ranking[ranking["mean_value"].notna()].copy()
invalid = ranking[ranking["mean_value"].isna()].copy()

# Rank only the valid ones (descending); convert to int safely
valid["rank"] = valid["mean_value"].rank(method="min", ascending=False).astype(int)

# For invalid ones, set rank to pandas NA (nullable Int) or a large number if you prefer
import pandas as pd
invalid["rank"] = pd.NA

# Combine back, put valid ranked items first
final_ranking = pd.concat([valid, invalid], ignore_index=True)
final_ranking = final_ranking.sort_values(by=["rank", "pollutant"], na_position="last").reset_index(drop=True)

print(final_ranking)

# Save cleaned hourly file and ranking
df.reset_index().rename(columns={"index":"datetime"}).to_csv("Paris_clean_hourly.csv", index=False)
final_ranking.to_csv("Paris_pollutant_ranking.csv", index=False)

print("Saved: Paris_clean_hourly.csv and Paris_pollutant_ranking.csv")
# Out:
#           pollutant   mean_value rank
# 0           methane  1595.517705    1
# 1    carbon_dioxide   490.637973    2
# 2   carbon_monoxide   204.889913    3
# 3  nitrogen_dioxide    23.134675    4
# 4              pm10    16.667219    5
# 5             pm2_5    10.909786    6
# 6           ammonia     2.435989    7
# 7   sulphur_dioxide     2.223148    8
# Saved: Paris_clean_hourly.csv and Paris_pollutant_ranking.csv

# %% [markdown]
# #London Cleaning

# %%
import pandas as pd
import numpy as np

fn = "London.csv"
df = pd.read_csv(fn)

print("shape:", df.shape)
print("columns:", df.columns.tolist())
print(df.head(5))
print("\nmissing per column:\n", df.isna().sum())
# Out:
# shape: (43872, 10)
# columns: ['date', 'pm10', 'pm2_5', 'carbon_monoxide', 'carbon_dioxide', 'nitrogen_dioxide', 'sulphur_dioxide', 'ozone', 'ammonia', 'methane']
#                         date  pm10  pm2_5  carbon_monoxide  carbon_dioxide  \
# 0  2020-01-01 00:00:00+00:00  42.1   32.8            339.0             NaN
# 1  2020-01-01 01:00:00+00:00  44.1   36.1            399.0             NaN
# 2  2020-01-01 02:00:00+00:00  41.6   38.7            422.0             NaN
# 3  2020-01-01 03:00:00+00:00  47.3   42.7            420.0             NaN
# 4  2020-01-01 04:00:00+00:00  50.9   44.8            367.0             NaN
#
#    nitrogen_dioxide  sulphur_dioxide  ozone  ammonia  methane
# 0              43.4              4.3    1.0      1.6      NaN
# 1              42.4              4.3    1.0      2.8      NaN
# 2              42.6              4.8    2.0      2.4      NaN
# 3              40.8              4.5    2.0      1.7      NaN
# 4              39.4              4.7    2.0      0.7      NaN
#
# missing per column:
#  date                    0
# pm10                    0
# pm2_5                   0
# carbon_monoxide         0
# carbon_dioxide      42240
# nitrogen_dioxide        0
# sulphur_dioxide         0
# ozone                   0
# ammonia                 0
# methane             42240
# dtype: int64

# %%
df.columns = (
    df.columns.str.strip()
              .str.lower()
              .str.replace(" ", "_")
              .str.replace("-", "_")
)

print(df.columns.tolist())
# Out:
# ['date', 'pm10', 'pm2_5', 'carbon_monoxide', 'carbon_dioxide', 'nitrogen_dioxide', 'sulphur_dioxide', 'ozone', 'ammonia', 'methane']

# %%
candidates = ["datetime", "date_time", "date", "time", "timestamp"]
dt_col = None

for c in candidates:
    if c in df.columns:
        dt_col = c
        break

if dt_col is None:
    raise RuntimeError("No datetime column found. Rename your column to one of: " + ", ".join(candidates))

df["datetime"] = pd.to_datetime(df[dt_col], errors="coerce")
print("Parsed datetime:", dt_col, " — nulls:", df["datetime"].isna().sum())

df = df[~df["datetime"].isna()].copy()
df = df.sort_values("datetime").reset_index(drop=True)

print("After datetime cleaning, rows:", len(df))
# Out:
# Parsed datetime: date  — nulls: 0
# After datetime cleaning, rows: 43872

# %%
pollutants = [
    "pm10","pm2_5","ammonia",
    "carbon_monoxide","nitrogen_dioxide",
    "carbon_dioxide","sulphur_dioxide","methane"
]

# try to fix common alternative column names
col_map = {}
for p in pollutants:
    if p not in df.columns:
        alternatives = [
            p.replace("_",""),
            p.replace("2_5","2.5"),
            p.replace("pm2_5","pm2.5"),
            p.replace("pm2_5","pm25"),
        ]
        for alt in alternatives:
            if alt in df.columns:
                col_map[alt] = p

if col_map:
    df = df.rename(columns=col_map)
    print("Renamed columns:", col_map)

missing = [p for p in pollutants if p not in df.columns]
if missing:
    print("Warning: Missing pollutant columns:", missing)

# convert to numeric
for p in pollutants:
    if p in df.columns:
        df[p] = (
            df[p].astype(str)
                 .str.replace("<","")
                 .str.replace(",","")
                 .str.strip()
        )
        df[p] = pd.to_numeric(df[p], errors="coerce")

# %%
# negative values → NaN
for p in pollutants:
    if p in df.columns:
        df.loc[df[p] < 0, p] = np.nan

# cap at 99.9 percentile (pollutant-dependent)
for p in pollutants:
    if p in df.columns:
        q = df[p].quantile(0.999)
        if pd.notna(q) and q > 0:
            df.loc[df[p] > q, p] = np.nan
        print(f"{p}: capped at {q}")
# Out:
# pm10: capped at 65.0
# pm2_5: capped at 50.01290000000081
# ammonia: capped at 11.412900000000809
# carbon_monoxide: capped at 639.0
# nitrogen_dioxide: capped at 80.81290000000081
# carbon_dioxide: capped at 773.7380000000003
# sulphur_dioxide: capped at 20.51290000000081
# methane: capped at 2721.4390000000044

# %%
df = df.set_index("datetime")

start = df.index.min().ceil("H")
end   = df.index.max().floor("H")

full_idx = pd.date_range(start=start, end=end, freq="H")

df = df.reindex(full_idx)
print("Reindexed to hourly:", len(df))
# Out:
# Reindexed to hourly: 43872
# /tmp/ipython-input-1351569827.py:3: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   start = df.index.min().ceil("H")
# /tmp/ipython-input-1351569827.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   end   = df.index.max().floor("H")
# /tmp/ipython-input-1351569827.py:6: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   full_idx = pd.date_range(start=start, end=end, freq="H")

# %%
numeric_cols = [c for c in pollutants if c in df.columns]

df[numeric_cols] = df[numeric_cols].interpolate(method="time", limit=24)
df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

print("Remaining NaNs:\n", df[numeric_cols].isna().sum())
# Out:
# Remaining NaNs:
#  pm10                    0
# pm2_5                   0
# ammonia                 0
# carbon_monoxide         0
# nitrogen_dioxide        0
# carbon_dioxide      42234
# sulphur_dioxide         0
# methane             42234
# dtype: int64
# /tmp/ipython-input-774743577.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

# %%
df["missing_pollutants"] = df[numeric_cols].isna().sum(axis=1)

summary = df[numeric_cols].describe().T
summary["missing"] = df[numeric_cols].isna().sum()

summary
# Out:
#                     count         mean         std     min     25%     50%  \
# pm10              43872.0    14.110897    8.205007     1.2     8.8    11.8
# pm2_5             43872.0     9.537358    6.531305     0.8     5.4     7.3
# ammonia           43872.0     2.162355    1.521149     0.0     1.1     1.8
# carbon_monoxide   43872.0   187.557263   67.177764    45.0   146.0   173.0
# nitrogen_dioxide  43872.0    20.601173   13.633088     1.8    10.6    16.4
# carbon_dioxide     1638.0   474.952381   43.802651   435.0   449.0   458.0
# sulphur_dioxide   43872.0     3.284765    2.444271     0.3     1.8     2.6
# methane            1638.0  1519.339438  216.422528  1356.0  1394.0  1428.0
#
#                       75%     max  missing
# pm10                16.70    65.0        0
# pm2_5               11.30    50.0        0
# ammonia              2.70    11.4        0
# carbon_monoxide    209.00   639.0        0
# nitrogen_dioxide    26.80    80.8        0
# carbon_dioxide     481.75   773.0    42234
# sulphur_dioxide      3.90    20.5        0
# methane           1538.75  2710.0    42234

# %%
means = df[numeric_cols].mean(skipna=True)              # may contain NaN for pollutant with no valid data
ranking = means.reset_index()
ranking.columns = ["pollutant", "mean_value"]

# Split valid (finite means) and invalid (NaN means)
valid = ranking[ranking["mean_value"].notna()].copy()
invalid = ranking[ranking["mean_value"].isna()].copy()

# Rank only the valid ones (descending); convert to int safely
valid["rank"] = valid["mean_value"].rank(method="min", ascending=False).astype(int)

# For invalid ones, set rank to pandas NA (nullable Int) or a large number if you prefer
import pandas as pd
invalid["rank"] = pd.NA

# Combine back, put valid ranked items first
final_ranking = pd.concat([valid, invalid], ignore_index=True)
final_ranking = final_ranking.sort_values(by=["rank", "pollutant"], na_position="last").reset_index(drop=True)

print(final_ranking)

# Save cleaned hourly file and ranking
df.reset_index().rename(columns={"index":"datetime"}).to_csv("London_clean_hourly.csv", index=False)
final_ranking.to_csv("London_pollutant_ranking.csv", index=False)

print("Saved: London_clean_hourly.csv and London_pollutant_ranking.csv")
# Out:
#           pollutant   mean_value rank
# 0           methane  1519.339438    1
# 1    carbon_dioxide   474.952381    2
# 2   carbon_monoxide   187.557263    3
# 3  nitrogen_dioxide    20.601173    4
# 4              pm10    14.110897    5
# 5             pm2_5     9.537358    6
# 6   sulphur_dioxide     3.284765    7
# 7           ammonia     2.162355    8
# Saved: London_clean_hourly.csv and London_pollutant_ranking.csv

# %% [markdown]
# #Madrid Cleaning

# %%
import pandas as pd
import numpy as np

fn = "Madrid.csv"
df = pd.read_csv(fn)

print("shape:", df.shape)
print("columns:", df.columns.tolist())
print(df.head(5))
print("\nmissing per column:\n", df.isna().sum())
# Out:
# shape: (43872, 10)
# columns: ['date', 'pm10', 'pm2_5', 'carbon_monoxide', 'carbon_dioxide', 'nitrogen_dioxide', 'sulphur_dioxide', 'ozone', 'ammonia', 'methane']
#                         date  pm10  pm2_5  carbon_monoxide  carbon_dioxide  \
# 0  2020-01-01 00:00:00+00:00  44.3   32.8            438.0             NaN
# 1  2020-01-01 01:00:00+00:00  46.2   32.8            375.0             NaN
# 2  2020-01-01 02:00:00+00:00  47.6   33.8            430.0             NaN
# 3  2020-01-01 03:00:00+00:00  50.4   35.3            398.0             NaN
# 4  2020-01-01 04:00:00+00:00  44.8   34.6            335.0             NaN
#
#    nitrogen_dioxide  sulphur_dioxide  ozone  ammonia  methane
# 0              60.7             11.7    0.0      1.7      NaN
# 1              55.1             12.0    0.0      0.8      NaN
# 2              53.5             11.7    0.0      0.7      NaN
# 3              52.8             11.6    1.0      0.4      NaN
# 4              50.5             10.0    1.0      0.5      NaN
#
# missing per column:
#  date                    0
# pm10                    0
# pm2_5                   0
# carbon_monoxide         0
# carbon_dioxide      42240
# nitrogen_dioxide        0
# sulphur_dioxide         0
# ozone                   0
# ammonia                 0
# methane             42240
# dtype: int64

# %%
df.columns = (
    df.columns.str.strip()
              .str.lower()
              .str.replace(" ", "_")
              .str.replace("-", "_")
)

print(df.columns.tolist())
# Out:
# ['date', 'pm10', 'pm2_5', 'carbon_monoxide', 'carbon_dioxide', 'nitrogen_dioxide', 'sulphur_dioxide', 'ozone', 'ammonia', 'methane']

# %%
candidates = ["datetime", "date_time", "date", "time", "timestamp"]
dt_col = None

for c in candidates:
    if c in df.columns:
        dt_col = c
        break

if dt_col is None:
    raise RuntimeError("No datetime column found. Rename your column to one of: " + ", ".join(candidates))

df["datetime"] = pd.to_datetime(df[dt_col], errors="coerce")
print("Parsed datetime:", dt_col, " — nulls:", df["datetime"].isna().sum())

df = df[~df["datetime"].isna()].copy()
df = df.sort_values("datetime").reset_index(drop=True)

print("After datetime cleaning, rows:", len(df))
# Out:
# Parsed datetime: date  — nulls: 0
# After datetime cleaning, rows: 43872

# %%
pollutants = [
    "pm10","pm2_5","ammonia",
    "carbon_monoxide","nitrogen_dioxide",
    "carbon_dioxide","sulphur_dioxide","methane"
]

# try to fix common alternative column names
col_map = {}
for p in pollutants:
    if p not in df.columns:
        alternatives = [
            p.replace("_",""),
            p.replace("2_5","2.5"),
            p.replace("pm2_5","pm2.5"),
            p.replace("pm2_5","pm25"),
        ]
        for alt in alternatives:
            if alt in df.columns:
                col_map[alt] = p

if col_map:
    df = df.rename(columns=col_map)
    print("Renamed columns:", col_map)

missing = [p for p in pollutants if p not in df.columns]
if missing:
    print("Warning: Missing pollutant columns:", missing)

# convert to numeric
for p in pollutants:
    if p in df.columns:
        df[p] = (
            df[p].astype(str)
                 .str.replace("<","")
                 .str.replace(",","")
                 .str.strip()
        )
        df[p] = pd.to_numeric(df[p], errors="coerce")

# %%
# negative values → NaN
for p in pollutants:
    if p in df.columns:
        df.loc[df[p] < 0, p] = np.nan

# cap at 99.9 percentile (pollutant-dependent)
for p in pollutants:
    if p in df.columns:
        q = df[p].quantile(0.999)
        if pd.notna(q) and q > 0:
            df.loc[df[p] > q, p] = np.nan
        print(f"{p}: capped at {q}")
# Out:
# pm10: capped at 126.89350000001214
# pm2_5: capped at 55.73870000000243
# ammonia: capped at 7.612900000000809
# carbon_monoxide: capped at 551.3870000000243
# nitrogen_dioxide: capped at 106.65160000000323
# carbon_dioxide: capped at 621.1070000000004
# sulphur_dioxide: capped at 25.6
# methane: capped at 1877.4760000000006

# %%
df = df.set_index("datetime")

start = df.index.min().ceil("H")
end   = df.index.max().floor("H")

full_idx = pd.date_range(start=start, end=end, freq="H")

df = df.reindex(full_idx)
print("Reindexed to hourly:", len(df))
# Out:
# Reindexed to hourly: 43872
# /tmp/ipython-input-1351569827.py:3: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   start = df.index.min().ceil("H")
# /tmp/ipython-input-1351569827.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   end   = df.index.max().floor("H")
# /tmp/ipython-input-1351569827.py:6: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   full_idx = pd.date_range(start=start, end=end, freq="H")

# %%
numeric_cols = [c for c in pollutants if c in df.columns]

df[numeric_cols] = df[numeric_cols].interpolate(method="time", limit=24)
df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

print("Remaining NaNs:\n", df[numeric_cols].isna().sum())
# Out:
# Remaining NaNs:
#  pm10                    0
# pm2_5                   0
# ammonia                 0
# carbon_monoxide         0
# nitrogen_dioxide        0
# carbon_dioxide      42234
# sulphur_dioxide         0
# methane             42234
# dtype: int64
# /tmp/ipython-input-774743577.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

# %%
df["missing_pollutants"] = df[numeric_cols].isna().sum(axis=1)

summary = df[numeric_cols].describe().T
summary["missing"] = df[numeric_cols].isna().sum()

summary
# Out:
#                     count         mean        std     min     25%     50%  \
# pm10              43872.0    16.357929  12.156858     1.3     8.7    13.0
# pm2_5             43872.0     9.654465   6.351801     1.1     5.4     8.1
# ammonia           43872.0     1.621650   1.046019     0.1     0.9     1.4
# carbon_monoxide   43872.0   186.621558  63.046081    72.0   141.0   174.0
# nitrogen_dioxide  43872.0    20.843040  16.916198     1.3     8.4    15.1
# carbon_dioxide     1638.0   481.870574  37.682908   435.0   453.0   472.0
# sulphur_dioxide   43872.0     3.682687   2.650638     0.2     2.1     3.1
# methane            1638.0  1467.325092  91.341044  1344.0  1399.0  1452.0
#
#                       75%     max  missing
# pm10                20.50   126.7        0
# pm2_5               11.90    55.7        0
# ammonia              2.10     7.6        0
# carbon_monoxide    217.00   551.0        0
# nitrogen_dioxide    28.40   106.6        0
# carbon_dioxide     499.00   620.0    42234
# sulphur_dioxide      4.50    25.6        0
# methane           1515.75  1876.0    42234

# %%
means = df[numeric_cols].mean(skipna=True)              # may contain NaN for pollutant with no valid data
ranking = means.reset_index()
ranking.columns = ["pollutant", "mean_value"]

# Split valid (finite means) and invalid (NaN means)
valid = ranking[ranking["mean_value"].notna()].copy()
invalid = ranking[ranking["mean_value"].isna()].copy()

# Rank only the valid ones (descending); convert to int safely
valid["rank"] = valid["mean_value"].rank(method="min", ascending=False).astype(int)

# For invalid ones, set rank to pandas NA (nullable Int) or a large number if you prefer
import pandas as pd
invalid["rank"] = pd.NA

# Combine back, put valid ranked items first
final_ranking = pd.concat([valid, invalid], ignore_index=True)
final_ranking = final_ranking.sort_values(by=["rank", "pollutant"], na_position="last").reset_index(drop=True)

print(final_ranking)

# Save cleaned hourly file and ranking
df.reset_index().rename(columns={"index":"datetime"}).to_csv("Madrid_clean_hourly.csv", index=False)
final_ranking.to_csv("Madrid_pollutant_ranking.csv", index=False)

print("Saved: Madrid_clean_hourly.csv and Madrid_pollutant_ranking.csv")
# Out:
#           pollutant   mean_value rank
# 0           methane  1467.325092    1
# 1    carbon_dioxide   481.870574    2
# 2   carbon_monoxide   186.621558    3
# 3  nitrogen_dioxide    20.843040    4
# 4              pm10    16.357929    5
# 5             pm2_5     9.654465    6
# 6   sulphur_dioxide     3.682687    7
# 7           ammonia     1.621650    8
# Saved: Madrid_clean_hourly.csv and Madrid_pollutant_ranking.csv

# %% [markdown]
# #Barcelona Cleaning

# %%
import pandas as pd
import numpy as np

fn = "Barcelona.csv"
df = pd.read_csv(fn)

print("shape:", df.shape)
print("columns:", df.columns.tolist())
print(df.head(5))
print("\nmissing per column:\n", df.isna().sum())
# Out:
# shape: (43872, 10)
# columns: ['date', 'pm10', 'pm2_5', 'carbon_monoxide', 'carbon_dioxide', 'nitrogen_dioxide', 'sulphur_dioxide', 'ozone', 'ammonia', 'methane']
#                         date  pm10  pm2_5  carbon_monoxide  carbon_dioxide  \
# 0  2020-01-01 00:00:00+00:00  21.1   23.5            263.0             NaN
# 1  2020-01-01 01:00:00+00:00  22.8   21.0            251.0             NaN
# 2  2020-01-01 02:00:00+00:00  23.6   24.0            240.0             NaN
# 3  2020-01-01 03:00:00+00:00  21.8   19.8            227.0             NaN
# 4  2020-01-01 04:00:00+00:00  21.0   16.3            228.0             NaN
#
#    nitrogen_dioxide  sulphur_dioxide  ozone  ammonia  methane
# 0              21.3              3.0   16.0      3.1      NaN
# 1              31.9              3.0   11.0      2.7      NaN
# 2              33.1              3.2   14.0      2.5      NaN
# 3              26.8              1.9   15.0      2.4      NaN
# 4              29.6              2.5    9.0      2.9      NaN
#
# missing per column:
#  date                    0
# pm10                    0
# pm2_5                   0
# carbon_monoxide         0
# carbon_dioxide      42240
# nitrogen_dioxide        0
# sulphur_dioxide         0
# ozone                   0
# ammonia                 0
# methane             42240
# dtype: int64

# %%
df.columns = (
    df.columns.str.strip()
              .str.lower()
              .str.replace(" ", "_")
              .str.replace("-", "_")
)

print(df.columns.tolist())
# Out:
# ['date', 'pm10', 'pm2_5', 'carbon_monoxide', 'carbon_dioxide', 'nitrogen_dioxide', 'sulphur_dioxide', 'ozone', 'ammonia', 'methane']

# %%
candidates = ["datetime", "date_time", "date", "time", "timestamp"]
dt_col = None

for c in candidates:
    if c in df.columns:
        dt_col = c
        break

if dt_col is None:
    raise RuntimeError("No datetime column found. Rename your column to one of: " + ", ".join(candidates))

df["datetime"] = pd.to_datetime(df[dt_col], errors="coerce")
print("Parsed datetime:", dt_col, " — nulls:", df["datetime"].isna().sum())

df = df[~df["datetime"].isna()].copy()
df = df.sort_values("datetime").reset_index(drop=True)

print("After datetime cleaning, rows:", len(df))
# Out:
# Parsed datetime: date  — nulls: 0
# After datetime cleaning, rows: 43872

# %%
pollutants = [
    "pm10","pm2_5","ammonia",
    "carbon_monoxide","nitrogen_dioxide",
    "carbon_dioxide","sulphur_dioxide","methane"
]

# try to fix common alternative column names
col_map = {}
for p in pollutants:
    if p not in df.columns:
        alternatives = [
            p.replace("_",""),
            p.replace("2_5","2.5"),
            p.replace("pm2_5","pm2.5"),
            p.replace("pm2_5","pm25"),
        ]
        for alt in alternatives:
            if alt in df.columns:
                col_map[alt] = p

if col_map:
    df = df.rename(columns=col_map)
    print("Renamed columns:", col_map)

missing = [p for p in pollutants if p not in df.columns]
if missing:
    print("Warning: Missing pollutant columns:", missing)

# convert to numeric
for p in pollutants:
    if p in df.columns:
        df[p] = (
            df[p].astype(str)
                 .str.replace("<","")
                 .str.replace(",","")
                 .str.strip()
        )
        df[p] = pd.to_numeric(df[p], errors="coerce")

# %%
# negative values → NaN
for p in pollutants:
    if p in df.columns:
        df.loc[df[p] < 0, p] = np.nan

# cap at 99.9 percentile (pollutant-dependent)
for p in pollutants:
    if p in df.columns:
        q = df[p].quantile(0.999)
        if pd.notna(q) and q > 0:
            df.loc[df[p] > q, p] = np.nan
        print(f"{p}: capped at {q}")
# Out:
# pm10: capped at 79.32580000000162
# pm2_5: capped at 57.477400000004856
# ammonia: capped at 16.725800000001616
# carbon_monoxide: capped at 487.1290000000081
# nitrogen_dioxide: capped at 82.6
# carbon_dioxide: capped at 574.3690000000001
# sulphur_dioxide: capped at 21.725800000001616
# methane: capped at 2000.1070000000004

# %%
df = df.set_index("datetime")

start = df.index.min().ceil("H")
end   = df.index.max().floor("H")

full_idx = pd.date_range(start=start, end=end, freq="H")

df = df.reindex(full_idx)
print("Reindexed to hourly:", len(df))
# Out:
# Reindexed to hourly: 43872
# /tmp/ipython-input-1351569827.py:3: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   start = df.index.min().ceil("H")
# /tmp/ipython-input-1351569827.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   end   = df.index.max().floor("H")
# /tmp/ipython-input-1351569827.py:6: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   full_idx = pd.date_range(start=start, end=end, freq="H")

# %%
numeric_cols = [c for c in pollutants if c in df.columns]

df[numeric_cols] = df[numeric_cols].interpolate(method="time", limit=24)
df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

print("Remaining NaNs:\n", df[numeric_cols].isna().sum())
# Out:
# Remaining NaNs:
#  pm10                    0
# pm2_5                   0
# ammonia                 0
# carbon_monoxide         0
# nitrogen_dioxide        0
# carbon_dioxide      42234
# sulphur_dioxide         0
# methane             42234
# dtype: int64
# /tmp/ipython-input-774743577.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

# %%
df["missing_pollutants"] = df[numeric_cols].isna().sum(axis=1)

summary = df[numeric_cols].describe().T
summary["missing"] = df[numeric_cols].isna().sum()

summary
# Out:
#                     count         mean         std     min     25%     50%  \
# pm10              43872.0    21.677278   10.521202     2.4    14.4    19.7
# pm2_5             43872.0    14.385553    7.989133     1.5     8.7    12.6
# ammonia           43872.0     3.496933    2.811504     0.1     1.3     2.6
# carbon_monoxide   43872.0   201.976466   55.889253    67.0   164.0   196.0
# nitrogen_dioxide  43872.0    27.147944   14.644929     3.0    15.1    24.7
# carbon_dioxide     1638.0   470.886752   25.752763   438.0   449.0   465.5
# sulphur_dioxide   43872.0     4.183639    2.267368     0.9     2.7     3.6
# methane            1638.0  1515.337912  116.204221  1340.0  1414.0  1499.0
#
#                      75%     max  missing
# pm10                26.6    79.3        0
# pm2_5               18.1    57.4        0
# ammonia              5.0    16.7        0
# carbon_monoxide    231.0   487.0        0
# nitrogen_dioxide    36.5    82.6        0
# carbon_dioxide     486.0   574.0    42234
# sulphur_dioxide      5.1    21.7        0
# methane           1591.0  1999.0    42234

# %%
means = df[numeric_cols].mean(skipna=True)              # may contain NaN for pollutant with no valid data
ranking = means.reset_index()
ranking.columns = ["pollutant", "mean_value"]

# Split valid (finite means) and invalid (NaN means)
valid = ranking[ranking["mean_value"].notna()].copy()
invalid = ranking[ranking["mean_value"].isna()].copy()

# Rank only the valid ones (descending); convert to int safely
valid["rank"] = valid["mean_value"].rank(method="min", ascending=False).astype(int)

# For invalid ones, set rank to pandas NA (nullable Int) or a large number if you prefer
import pandas as pd
invalid["rank"] = pd.NA

# Combine back, put valid ranked items first
final_ranking = pd.concat([valid, invalid], ignore_index=True)
final_ranking = final_ranking.sort_values(by=["rank", "pollutant"], na_position="last").reset_index(drop=True)

print(final_ranking)

# Save cleaned hourly file and ranking
df.reset_index().rename(columns={"index":"datetime"}).to_csv("Barcelona_clean_hourly.csv", index=False)
final_ranking.to_csv("Barcelona_pollutant_ranking.csv", index=False)

print("Saved: Barcelona_clean_hourly.csv and Barcelona_pollutant_ranking.csv")
# Out:
#           pollutant   mean_value rank
# 0           methane  1515.337912    1
# 1    carbon_dioxide   470.886752    2
# 2   carbon_monoxide   201.976466    3
# 3  nitrogen_dioxide    27.147944    4
# 4              pm10    21.677278    5
# 5             pm2_5    14.385553    6
# 6   sulphur_dioxide     4.183639    7
# 7           ammonia     3.496933    8
# Saved: Barcelona_clean_hourly.csv and Barcelona_pollutant_ranking.csv

# %% [markdown]
# CLUSTERING PROCESS (HIERARCHICAL CLUSTERING)

# %%
# Load each city’s pollutant mean file
mos = pd.read_csv("Moscow_pollutant_ranking.csv")
par = pd.read_csv("Paris_pollutant_ranking.csv")
lon = pd.read_csv("London_pollutant_ranking.csv")
mad = pd.read_csv("Madrid_pollutant_ranking.csv")
bar = pd.read_csv("Barcelona_pollutant_ranking.csv")

# Add city names
mos["city"] = "Moscow"
par["city"] = "Paris"
lon["city"] = "London"
mad["city"] = "Madrid"
bar["city"] = "Barcelona"

# Combine into one table
df_means = pd.concat([mos, par, lon, mad, bar], ignore_index=True)

df_means
# Out:
#            pollutant   mean_value  rank       city
# 0            methane  1739.286325     1     Moscow
# 1     carbon_dioxide   481.507326     2     Moscow
# 2    carbon_monoxide   344.664256     3     Moscow
# 3   nitrogen_dioxide    36.931041     4     Moscow
# 4    sulphur_dioxide    32.031728     5     Moscow
# 5               pm10    28.788225     6     Moscow
# 6              pm2_5    22.564930     7     Moscow
# 7            ammonia     1.689878     8     Moscow
# 8            methane  1595.517705     1      Paris
# 9     carbon_dioxide   490.637973     2      Paris
# 10   carbon_monoxide   204.889913     3      Paris
# 11  nitrogen_dioxide    23.134675     4      Paris
# 12              pm10    16.667219     5      Paris
# 13             pm2_5    10.909786     6      Paris
# 14           ammonia     2.435989     7      Paris
# 15   sulphur_dioxide     2.223148     8      Paris
# 16           methane  1519.339438     1     London
# 17    carbon_dioxide   474.952381     2     London
# 18   carbon_monoxide   187.557263     3     London
# 19  nitrogen_dioxide    20.601173     4     London
# 20              pm10    14.110897     5     London
# 21             pm2_5     9.537358     6     London
# 22   sulphur_dioxide     3.284765     7     London
# 23           ammonia     2.162355     8     London
# 24           methane  1467.325092     1     Madrid
# 25    carbon_dioxide   481.870574     2     Madrid
# 26   carbon_monoxide   186.621558     3     Madrid
# 27  nitrogen_dioxide    20.843040     4     Madrid
# 28              pm10    16.357929     5     Madrid
# 29             pm2_5     9.654465     6     Madrid
# 30   sulphur_dioxide     3.682687     7     Madrid
# 31           ammonia     1.621650     8     Madrid
# 32           methane  1515.337912     1  Barcelona
# 33    carbon_dioxide   470.886752     2  Barcelona
# 34   carbon_monoxide   201.976466     3  Barcelona
# 35  nitrogen_dioxide    27.147944     4  Barcelona
# 36              pm10    21.677278     5  Barcelona
# 37             pm2_5    14.385553     6  Barcelona
# 38   sulphur_dioxide     4.183639     7  Barcelona
# 39           ammonia     3.496933     8  Barcelona

# %%
df_city = df_means.pivot(index="city", columns="pollutant", values="mean_value")

df_city
# Out:
# pollutant   ammonia  carbon_dioxide  carbon_monoxide      methane  \
# city
# Barcelona  3.496933      470.886752       201.976466  1515.337912
# London     2.162355      474.952381       187.557263  1519.339438
# Madrid     1.621650      481.870574       186.621558  1467.325092
# Moscow     1.689878      481.507326       344.664256  1739.286325
# Paris      2.435989      490.637973       204.889913  1595.517705
#
# pollutant  nitrogen_dioxide       pm10      pm2_5  sulphur_dioxide
# city
# Barcelona         27.147944  21.677278  14.385553         4.183639
# London            20.601173  14.110897   9.537358         3.284765
# Madrid            20.843040  16.357929   9.654465         3.682687
# Moscow            36.931041  28.788225  22.564930        32.031728
# Paris             23.134675  16.667219  10.909786         2.223148

# %%
import numpy as np
import pandas as pd

try:
    df_city
except NameError:
    # replace filename if needed
    df_city = pd.read_csv("df_city.csv", index_col=0)

print("Original df_city:\n")
display(df_city)

# Replace inf with NaN
df_city = df_city.replace([np.inf, -np.inf], np.nan)

# Show NaN summary
print("\nNaN per column before cleaning:")
print(df_city.isna().sum())

# Drop columns that are entirely NaN (like ammonia)
all_nan_cols = df_city.columns[df_city.isna().all()].tolist()
if all_nan_cols:
    print("\nDropping columns with all NaN:", all_nan_cols)
    df_city = df_city.drop(columns=all_nan_cols)

# If any columns have many NaNs (>80%) drop them:
too_many = df_city.columns[df_city.isna().mean() > 0.8].tolist()
if too_many:
    print("Dropping columns with >80% NaN:", too_many)
    df_city = df_city.drop(columns=too_many)

# Impute remaining NaNs with column median (safe for small table)
if df_city.isna().any().any():
    print("Imputing remaining NaNs with column median.")
    df_city = df_city.fillna(df_city.median())

print("\nPost-cleaning df_city:")
display(df_city)
# Out:
# Original df_city:
# pollutant   ammonia  carbon_dioxide  carbon_monoxide      methane  \
# city
# Barcelona  3.496933      470.886752       201.976466  1515.337912
# London     2.162355      474.952381       187.557263  1519.339438
# Madrid     1.621650      481.870574       186.621558  1467.325092
# Moscow     1.689878      481.507326       344.664256  1739.286325
# Paris      2.435989      490.637973       204.889913  1595.517705
#
# pollutant  nitrogen_dioxide       pm10      pm2_5  sulphur_dioxide
# city
# Barcelona         27.147944  21.677278  14.385553         4.183639
# London            20.601173  14.110897   9.537358         3.284765
# Madrid            20.843040  16.357929   9.654465         3.682687
# Moscow            36.931041  28.788225  22.564930        32.031728
# Paris             23.134675  16.667219  10.909786         2.223148
# NaN per column before cleaning:
# pollutant
# ammonia             0
# carbon_dioxide      0
# carbon_monoxide     0
# methane             0
# nitrogen_dioxide    0
# pm10                0
# pm2_5               0
# sulphur_dioxide     0
# dtype: int64
#
# Post-cleaning df_city:
# pollutant   ammonia  carbon_dioxide  carbon_monoxide      methane  \
# city
# Barcelona  3.496933      470.886752       201.976466  1515.337912
# London     2.162355      474.952381       187.557263  1519.339438
# Madrid     1.621650      481.870574       186.621558  1467.325092
# Moscow     1.689878      481.507326       344.664256  1739.286325
# Paris      2.435989      490.637973       204.889913  1595.517705
#
# pollutant  nitrogen_dioxide       pm10      pm2_5  sulphur_dioxide
# city
# Barcelona         27.147944  21.677278  14.385553         4.183639
# London            20.601173  14.110897   9.537358         3.284765
# Madrid            20.843040  16.357929   9.654465         3.682687
# Moscow            36.931041  28.788225  22.564930        32.031728
# Paris             23.134675  16.667219  10.909786         2.223148

# %%
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
import matplotlib.pyplot as plt

# convert to float matrix
X = df_city.values.astype(float)

# Standardize
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# linkage
Z = linkage(X_scaled, method="ward")

# plot dendrogram
plt.figure(figsize=(6,4))
dendrogram(Z, labels=df_city.index.tolist(), leaf_rotation=0, leaf_font_size=12)
plt.title("Hierarchical clustering (Ward) — European cities")
plt.ylabel("Linkage distance")
plt.tight_layout()
plt.show()

# assign cluster labels (choose k, e.g., 2)
k = 2
labels = fcluster(Z, t=k, criterion="maxclust")
df_city["cluster"] = labels
print("\nAssigned clusters:")
display(df_city[["cluster"]])
# Out:
# Assigned clusters:
# pollutant  cluster
# city
# Barcelona        1
# London           1
# Madrid           1
# Moscow           2
# Paris            1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(9, 6)) # Increased figure size for better label visibility use standardized values for heatmap to show relative differences
X_scaled_df = pd.DataFrame(X_scaled, index=df_city.index, columns=df_city.columns[:-1] if "cluster" in df_city.columns else df_city.columns)
sns.heatmap(X_scaled_df, annot=True, fmt=".2f", cmap="vlag", cbar_kws={"label": "z-score"})
plt.title("Standardized pollutant means (European cities)")
plt.ylabel("City")
plt.xlabel("Pollutant")
plt.yticks(rotation=0) # Rotate city names to be horizontal
plt.tight_layout()
plt.show()
