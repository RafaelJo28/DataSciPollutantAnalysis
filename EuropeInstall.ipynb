# %%
# !pip install openmeteo-requests
# !pip install requests-cache retry-requests numpy pandas
# Out:
# Collecting openmeteo-requests
#   Downloading openmeteo_requests-1.7.5-py3-none-any.whl.metadata (11 kB)
# Collecting niquests>=3.15.2 (from openmeteo-requests)
#   Downloading niquests-3.17.0-py3-none-any.whl.metadata (17 kB)
# Collecting openmeteo-sdk>=1.22.0 (from openmeteo-requests)
#   Downloading openmeteo_sdk-1.25.0-py3-none-any.whl.metadata (935 bytes)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from niquests>=3.15.2->openmeteo-requests) (3.4.4)
# Collecting urllib3-future<3,>=2.13.903 (from niquests>=3.15.2->openmeteo-requests)
#   Downloading urllib3_future-2.15.901-py3-none-any.whl.metadata (16 kB)
# Collecting wassima<3,>=1.0.1 (from niquests>=3.15.2->openmeteo-requests)
#   Downloading wassima-2.0.4-py3-none-any.whl.metadata (3.7 kB)
# Collecting flatbuffers==25.9.23 (from openmeteo-sdk>=1.22.0->openmeteo-requests)
#   Downloading flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: h11<1.0.0,>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo-requests) (0.16.0)
# Collecting jh2<6.0.0,>=5.0.3 (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo-requests)
#   Downloading jh2-5.0.10-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting qh3<2.0.0,>=1.5.4 (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo-requests)
#   Downloading qh3-1.5.6-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Downloading openmeteo_requests-1.7.5-py3-none-any.whl (7.1 kB)
# Downloading niquests-3.17.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.4/183.4 kB 6.9 MB/s eta 0:00:00
# Downloading openmeteo_sdk-1.25.0-py3-none-any.whl (19 kB)
# Downloading flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Downloading urllib3_future-2.15.901-py3-none-any.whl (684 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 684.7/684.7 kB 18.1 MB/s eta 0:00:00
# Downloading wassima-2.0.4-py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.3/144.3 kB 5.8 MB/s eta 0:00:00
# Downloading jh2-5.0.10-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (394 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.1/394.1 kB 13.7 MB/s eta 0:00:00
# Downloading qh3-1.5.6-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 27.8 MB/s eta 0:00:00
# Installing collected packages: flatbuffers, wassima, qh3, openmeteo-sdk, jh2, urllib3-future, niquests, openmeteo-requests
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 25.12.19
#     Uninstalling flatbuffers-25.12.19:
#       Successfully uninstalled flatbuffers-25.12.19
# Successfully installed flatbuffers-25.9.23 jh2-5.0.10 niquests-3.17.0 openmeteo-requests-1.7.5 openmeteo-sdk-1.25.0 qh3-1.5.6 urllib3-future-2.15.901 wassima-2.0.4
# Collecting requests-cache
#   Downloading requests_cache-1.3.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting retry-requests
#   Downloading retry_requests-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache) (25.4.0)
# Collecting cattrs>=22.2 (from requests-cache)
#   Downloading cattrs-25.3.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache) (4.5.1)
# Requirement already satisfied: requests>=2.22 in /usr/local/lib/python3.12/dist-packages (from requests-cache) (2.32.4)
# Collecting url-normalize>=2.0 (from requests-cache)
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: urllib3>=1.25.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from cattrs>=22.2->requests-cache) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.22->requests-cache) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.22->requests-cache) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.22->requests-cache) (2026.1.4)
# Downloading requests_cache-1.3.0-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 2.7 MB/s eta 0:00:00
# Downloading retry_requests-2.0.0-py3-none-any.whl (15 kB)
# Downloading cattrs-25.3.0-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 kB 6.3 MB/s eta 0:00:00
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: url-normalize, cattrs, retry-requests, requests-cache
# Successfully installed cattrs-25.3.0 requests-cache-1.3.0 retry-requests-2.0.0 url-normalize-2.2.1

# %% [markdown]
# #Moscow saving

# %%
import openmeteo_requests

import pandas as pd
import requests_cache
from retry_requests import retry

# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://air-quality-api.open-meteo.com/v1/air-quality"
params = {
	"latitude": 55.7522,
	"longitude": 37.6156,
	"hourly": ["pm10", "pm2_5", "carbon_monoxide", "carbon_dioxide", "nitrogen_dioxide", "sulphur_dioxide", "ozone", "ammonia", "methane"],
	"start_date": "2020-01-01",
	"end_date": "2025-01-01",
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates: {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation: {response.Elevation()} m asl")
print(f"Timezone difference to GMT+0: {response.UtcOffsetSeconds()}s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_pm10 = hourly.Variables(0).ValuesAsNumpy()
hourly_pm2_5 = hourly.Variables(1).ValuesAsNumpy()
hourly_carbon_monoxide = hourly.Variables(2).ValuesAsNumpy()
hourly_carbon_dioxide = hourly.Variables(3).ValuesAsNumpy()
hourly_nitrogen_dioxide = hourly.Variables(4).ValuesAsNumpy()
hourly_sulphur_dioxide = hourly.Variables(5).ValuesAsNumpy()
hourly_ozone = hourly.Variables(6).ValuesAsNumpy()
hourly_ammonia = hourly.Variables(7).ValuesAsNumpy()
hourly_methane = hourly.Variables(8).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end =  pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["pm10"] = hourly_pm10
hourly_data["pm2_5"] = hourly_pm2_5
hourly_data["carbon_monoxide"] = hourly_carbon_monoxide
hourly_data["carbon_dioxide"] = hourly_carbon_dioxide
hourly_data["nitrogen_dioxide"] = hourly_nitrogen_dioxide
hourly_data["sulphur_dioxide"] = hourly_sulphur_dioxide
hourly_data["ozone"] = hourly_ozone
hourly_data["ammonia"] = hourly_ammonia
hourly_data["methane"] = hourly_methane

hourly_dataframe = pd.DataFrame(data = hourly_data)
print("\nHourly data\n", hourly_dataframe)
# Out:
# Coordinates: 55.80000305175781°N 37.60000228881836°E
# Elevation: 141.0 m asl
# Timezone difference to GMT+0: 0s
#
# Hourly data
#                             date       pm10  pm2_5  carbon_monoxide  \
# 0     2020-01-01 00:00:00+00:00   9.800000    7.7            208.0
# 1     2020-01-01 01:00:00+00:00  13.000000    9.6            217.0
# 2     2020-01-01 02:00:00+00:00  12.100000    9.2            205.0
# 3     2020-01-01 03:00:00+00:00  10.600000    7.5            189.0
# 4     2020-01-01 04:00:00+00:00   9.800000    7.0            189.0
# ...                         ...        ...    ...              ...
# 43867 2025-01-01 19:00:00+00:00  15.300000   13.5            286.0
# 43868 2025-01-01 20:00:00+00:00  15.900000   14.2            264.0
# 43869 2025-01-01 21:00:00+00:00  16.500000   14.9            238.0
# 43870 2025-01-01 22:00:00+00:00  15.900000   14.3            221.0
# 43871 2025-01-01 23:00:00+00:00  16.200001   14.9            207.0
#
#        carbon_dioxide  nitrogen_dioxide  sulphur_dioxide  ozone  ammonia  \
# 0                 NaN         26.000000        17.799999   28.0      0.3
# 1                 NaN         30.100000        18.799999   25.0      0.4
# 2                 NaN         29.299999        19.100000   20.0      0.3
# 3                 NaN         21.100000        15.600000   28.0      0.2
# 4                 NaN         19.500000        12.800000   33.0      0.3
# ...               ...               ...              ...    ...      ...
# 43867           465.0         24.700001        20.799999   42.0      0.2
# 43868           461.0         20.000000        19.000000   42.0      0.2
# 43869           457.0         16.900000        13.800000   42.0      0.2
# 43870           455.0         15.100000        13.300000   43.0      0.1
# 43871           454.0         14.500000        14.200000   45.0      0.1
#
#        methane
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 43867   1540.0
# 43868   1531.0
# 43869   1524.0
# 43870   1523.0
# 43871   1524.0
#
# [43872 rows x 10 columns]

# %%
hourly_dataframe.to_csv('Moscow.csv', index=False)

# %% [markdown]
# #Paris saving

# %%
import openmeteo_requests

import pandas as pd
import requests_cache
from retry_requests import retry

# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://air-quality-api.open-meteo.com/v1/air-quality"
params = {
	"latitude": 48.8534,
	"longitude": 2.3488,
	"hourly": ["pm10", "pm2_5", "carbon_monoxide", "carbon_dioxide", "nitrogen_dioxide", "sulphur_dioxide", "ozone", "ammonia", "methane"],
	"start_date": "2020-01-01",
	"end_date": "2025-01-01",
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates: {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation: {response.Elevation()} m asl")
print(f"Timezone difference to GMT+0: {response.UtcOffsetSeconds()}s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_pm10 = hourly.Variables(0).ValuesAsNumpy()
hourly_pm2_5 = hourly.Variables(1).ValuesAsNumpy()
hourly_carbon_monoxide = hourly.Variables(2).ValuesAsNumpy()
hourly_carbon_dioxide = hourly.Variables(3).ValuesAsNumpy()
hourly_nitrogen_dioxide = hourly.Variables(4).ValuesAsNumpy()
hourly_sulphur_dioxide = hourly.Variables(5).ValuesAsNumpy()
hourly_ozone = hourly.Variables(6).ValuesAsNumpy()
hourly_ammonia = hourly.Variables(7).ValuesAsNumpy()
hourly_methane = hourly.Variables(8).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end =  pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["pm10"] = hourly_pm10
hourly_data["pm2_5"] = hourly_pm2_5
hourly_data["carbon_monoxide"] = hourly_carbon_monoxide
hourly_data["carbon_dioxide"] = hourly_carbon_dioxide
hourly_data["nitrogen_dioxide"] = hourly_nitrogen_dioxide
hourly_data["sulphur_dioxide"] = hourly_sulphur_dioxide
hourly_data["ozone"] = hourly_ozone
hourly_data["ammonia"] = hourly_ammonia
hourly_data["methane"] = hourly_methane

hourly_dataframe = pd.DataFrame(data = hourly_data)
print("\nHourly data\n", hourly_dataframe)

# %%
hourly_dataframe.to_csv('Paris.csv', index=False)

# %% [markdown]
# #London saving

# %%
import openmeteo_requests

import pandas as pd
import requests_cache
from retry_requests import retry

# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://air-quality-api.open-meteo.com/v1/air-quality"
params = {
	"latitude": 51.5085,
	"longitude": -0.1257,
	"hourly": ["pm10", "pm2_5", "carbon_monoxide", "carbon_dioxide", "nitrogen_dioxide", "sulphur_dioxide", "ozone", "ammonia", "methane"],
	"start_date": "2020-01-01",
	"end_date": "2025-01-01",
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates: {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation: {response.Elevation()} m asl")
print(f"Timezone difference to GMT+0: {response.UtcOffsetSeconds()}s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_pm10 = hourly.Variables(0).ValuesAsNumpy()
hourly_pm2_5 = hourly.Variables(1).ValuesAsNumpy()
hourly_carbon_monoxide = hourly.Variables(2).ValuesAsNumpy()
hourly_carbon_dioxide = hourly.Variables(3).ValuesAsNumpy()
hourly_nitrogen_dioxide = hourly.Variables(4).ValuesAsNumpy()
hourly_sulphur_dioxide = hourly.Variables(5).ValuesAsNumpy()
hourly_ozone = hourly.Variables(6).ValuesAsNumpy()
hourly_ammonia = hourly.Variables(7).ValuesAsNumpy()
hourly_methane = hourly.Variables(8).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end =  pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["pm10"] = hourly_pm10
hourly_data["pm2_5"] = hourly_pm2_5
hourly_data["carbon_monoxide"] = hourly_carbon_monoxide
hourly_data["carbon_dioxide"] = hourly_carbon_dioxide
hourly_data["nitrogen_dioxide"] = hourly_nitrogen_dioxide
hourly_data["sulphur_dioxide"] = hourly_sulphur_dioxide
hourly_data["ozone"] = hourly_ozone
hourly_data["ammonia"] = hourly_ammonia
hourly_data["methane"] = hourly_methane

hourly_dataframe = pd.DataFrame(data = hourly_data)
print("\nHourly data\n", hourly_dataframe)
# Out:
# Coordinates: 51.5°N -0.10000038146972656°E
# Elevation: 23.0 m asl
# Timezone difference to GMT+0: 0s
#
# Hourly data
#                             date       pm10      pm2_5  carbon_monoxide  \
# 0     2020-01-01 00:00:00+00:00  42.099998  32.799999            339.0
# 1     2020-01-01 01:00:00+00:00  44.099998  36.099998            399.0
# 2     2020-01-01 02:00:00+00:00  41.599998  38.700001            422.0
# 3     2020-01-01 03:00:00+00:00  47.299999  42.700001            420.0
# 4     2020-01-01 04:00:00+00:00  50.900002  44.799999            367.0
# ...                         ...        ...        ...              ...
# 43867 2025-01-01 19:00:00+00:00   7.200000   5.800000            194.0
# 43868 2025-01-01 20:00:00+00:00   8.500000   6.300000            189.0
# 43869 2025-01-01 21:00:00+00:00   9.600000   6.800000            183.0
# 43870 2025-01-01 22:00:00+00:00  10.900000   7.900000            187.0
# 43871 2025-01-01 23:00:00+00:00  11.800000   9.400000            203.0
#
#        carbon_dioxide  nitrogen_dioxide  sulphur_dioxide  ozone  ammonia  \
# 0                 NaN         43.400002              4.3    1.0      1.6
# 1                 NaN         42.400002              4.3    1.0      2.8
# 2                 NaN         42.599998              4.8    2.0      2.4
# 3                 NaN         40.799999              4.5    2.0      1.7
# 4                 NaN         39.400002              4.7    2.0      0.7
# ...               ...               ...              ...    ...      ...
# 43867           456.0         34.400002              2.9   41.0      1.3
# 43868           459.0         30.600000              3.2   43.0      1.1
# 43869           462.0         32.000000              3.5   46.0      1.3
# 43870           464.0         34.799999              4.1   35.0      1.5
# 43871           466.0         43.799999              5.8   29.0      2.3
#
#        methane
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 43867   1386.0
# 43868   1390.0
# 43869   1397.0
# 43870   1409.0
# 43871   1423.0
#
# [43872 rows x 10 columns]

# %%
hourly_dataframe.to_csv('London.csv', index=False)

# %% [markdown]
# #Madrid saving

# %%
import openmeteo_requests

import pandas as pd
import requests_cache
from retry_requests import retry

# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://air-quality-api.open-meteo.com/v1/air-quality"
params = {
	"latitude": 40.4165,
	"longitude": -3.7026,
	"hourly": ["pm10", "pm2_5", "carbon_monoxide", "carbon_dioxide", "nitrogen_dioxide", "sulphur_dioxide", "ozone", "ammonia", "methane"],
	"start_date": "2020-01-01",
	"end_date": "2025-01-01",
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates: {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation: {response.Elevation()} m asl")
print(f"Timezone difference to GMT+0: {response.UtcOffsetSeconds()}s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_pm10 = hourly.Variables(0).ValuesAsNumpy()
hourly_pm2_5 = hourly.Variables(1).ValuesAsNumpy()
hourly_carbon_monoxide = hourly.Variables(2).ValuesAsNumpy()
hourly_carbon_dioxide = hourly.Variables(3).ValuesAsNumpy()
hourly_nitrogen_dioxide = hourly.Variables(4).ValuesAsNumpy()
hourly_sulphur_dioxide = hourly.Variables(5).ValuesAsNumpy()
hourly_ozone = hourly.Variables(6).ValuesAsNumpy()
hourly_ammonia = hourly.Variables(7).ValuesAsNumpy()
hourly_methane = hourly.Variables(8).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end =  pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["pm10"] = hourly_pm10
hourly_data["pm2_5"] = hourly_pm2_5
hourly_data["carbon_monoxide"] = hourly_carbon_monoxide
hourly_data["carbon_dioxide"] = hourly_carbon_dioxide
hourly_data["nitrogen_dioxide"] = hourly_nitrogen_dioxide
hourly_data["sulphur_dioxide"] = hourly_sulphur_dioxide
hourly_data["ozone"] = hourly_ozone
hourly_data["ammonia"] = hourly_ammonia
hourly_data["methane"] = hourly_methane

hourly_dataframe = pd.DataFrame(data = hourly_data)
print("\nHourly data\n", hourly_dataframe)

# %%
hourly_dataframe.to_csv('Madrid.csv', index=False)

# %% [markdown]
# #Barcelona saving

# %%
import openmeteo_requests

import pandas as pd
import requests_cache
from retry_requests import retry

# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://air-quality-api.open-meteo.com/v1/air-quality"
params = {
	"latitude": 41.3888,
	"longitude": 2.159,
	"hourly": ["pm10", "pm2_5", "carbon_monoxide", "carbon_dioxide", "nitrogen_dioxide", "sulphur_dioxide", "ozone", "ammonia", "methane"],
	"start_date": "2020-01-01",
	"end_date": "2025-01-01",
}
responses = openmeteo.weather_api(url, params=params)

# Process first location. Add a for-loop for multiple locations or weather models
response = responses[0]
print(f"Coordinates: {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation: {response.Elevation()} m asl")
print(f"Timezone difference to GMT+0: {response.UtcOffsetSeconds()}s")

# Process hourly data. The order of variables needs to be the same as requested.
hourly = response.Hourly()
hourly_pm10 = hourly.Variables(0).ValuesAsNumpy()
hourly_pm2_5 = hourly.Variables(1).ValuesAsNumpy()
hourly_carbon_monoxide = hourly.Variables(2).ValuesAsNumpy()
hourly_carbon_dioxide = hourly.Variables(3).ValuesAsNumpy()
hourly_nitrogen_dioxide = hourly.Variables(4).ValuesAsNumpy()
hourly_sulphur_dioxide = hourly.Variables(5).ValuesAsNumpy()
hourly_ozone = hourly.Variables(6).ValuesAsNumpy()
hourly_ammonia = hourly.Variables(7).ValuesAsNumpy()
hourly_methane = hourly.Variables(8).ValuesAsNumpy()

hourly_data = {"date": pd.date_range(
	start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
	end =  pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = hourly.Interval()),
	inclusive = "left"
)}

hourly_data["pm10"] = hourly_pm10
hourly_data["pm2_5"] = hourly_pm2_5
hourly_data["carbon_monoxide"] = hourly_carbon_monoxide
hourly_data["carbon_dioxide"] = hourly_carbon_dioxide
hourly_data["nitrogen_dioxide"] = hourly_nitrogen_dioxide
hourly_data["sulphur_dioxide"] = hourly_sulphur_dioxide
hourly_data["ozone"] = hourly_ozone
hourly_data["ammonia"] = hourly_ammonia
hourly_data["methane"] = hourly_methane

hourly_dataframe = pd.DataFrame(data = hourly_data)
print("\nHourly data\n", hourly_dataframe)
# Out:
# Coordinates: 41.400001525878906°N 2.200000762939453°E
# Elevation: 44.0 m asl
# Timezone difference to GMT+0: 0s
#
# Hourly data
#                             date       pm10      pm2_5  carbon_monoxide  \
# 0     2020-01-01 00:00:00+00:00  21.100000  23.500000            263.0
# 1     2020-01-01 01:00:00+00:00  22.799999  21.000000            251.0
# 2     2020-01-01 02:00:00+00:00  23.600000  24.000000            240.0
# 3     2020-01-01 03:00:00+00:00  21.799999  19.799999            227.0
# 4     2020-01-01 04:00:00+00:00  21.000000  16.299999            228.0
# ...                         ...        ...        ...              ...
# 43867 2025-01-01 19:00:00+00:00  41.099998  31.400000            367.0
# 43868 2025-01-01 20:00:00+00:00  49.799999  36.200001            383.0
# 43869 2025-01-01 21:00:00+00:00  54.599998  42.500000            421.0
# 43870 2025-01-01 22:00:00+00:00  48.599998  45.900002            373.0
# 43871 2025-01-01 23:00:00+00:00  45.299999  42.799999            309.0
#
#        carbon_dioxide  nitrogen_dioxide  sulphur_dioxide  ozone  ammonia  \
# 0                 NaN         21.299999         3.000000   16.0      3.1
# 1                 NaN         31.900000         3.000000   11.0      2.7
# 2                 NaN         33.099998         3.200000   14.0      2.5
# 3                 NaN         26.799999         1.900000   15.0      2.4
# 4                 NaN         29.600000         2.500000    9.0      2.9
# ...               ...               ...              ...    ...      ...
# 43867           505.0         97.699997        30.900000    4.0      6.6
# 43868           517.0        101.699997        37.200001    4.0      6.7
# 43869           521.0         86.099998        26.900000    2.0      7.6
# 43870           512.0         72.599998        15.800000    2.0      5.8
# 43871           496.0         55.400002        11.500000    7.0      5.9
#
#        methane
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 43867   1648.0
# 43868   1709.0
# 43869   1744.0
# 43870   1730.0
# 43871   1690.0
#
# [43872 rows x 10 columns]

# %%
hourly_dataframe.to_csv('Barcelona.csv', index=False)
