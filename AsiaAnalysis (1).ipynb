# %%
import pandas as pd

# %% [markdown]
# Beijing Analysis

# %%
beijing_df = pd.read_csv('/content/Beijing.csv')
print('\nBeijing Data:')
display(beijing_df.head())
# Out:
# Beijing Data:
#                         date  pm10  pm2_5  carbon_monoxide  carbon_dioxide  \
# 0  2020-01-01 00:00:00+00:00   NaN    NaN              NaN             NaN
# 1  2020-01-01 01:00:00+00:00   NaN    NaN              NaN             NaN
# 2  2020-01-01 02:00:00+00:00   NaN    NaN              NaN             NaN
# 3  2020-01-01 03:00:00+00:00   NaN    NaN              NaN             NaN
# 4  2020-01-01 04:00:00+00:00   NaN    NaN              NaN             NaN
#
#    nitrogen_dioxide  ammonia  methane  sulphur_dioxide  ozone
# 0               NaN      NaN      NaN              NaN    NaN
# 1               NaN      NaN      NaN              NaN    NaN
# 2               NaN      NaN      NaN              NaN    NaN
# 3               NaN      NaN      NaN              NaN    NaN
# 4               NaN      NaN      NaN              NaN    NaN

# %%
beijing_df
# Out:
#                             date  pm10  pm2_5  carbon_monoxide  \
# 0      2020-01-01 00:00:00+00:00   NaN    NaN              NaN
# 1      2020-01-01 01:00:00+00:00   NaN    NaN              NaN
# 2      2020-01-01 02:00:00+00:00   NaN    NaN              NaN
# 3      2020-01-01 03:00:00+00:00   NaN    NaN              NaN
# 4      2020-01-01 04:00:00+00:00   NaN    NaN              NaN
# ...                          ...   ...    ...              ...
# 43867  2025-01-01 19:00:00+00:00  62.9   60.5            365.0
# 43868  2025-01-01 20:00:00+00:00  50.1   48.4            369.0
# 43869  2025-01-01 21:00:00+00:00  46.7   45.5            492.0
# 43870  2025-01-01 22:00:00+00:00  50.9   49.9            821.0
# 43871  2025-01-01 23:00:00+00:00  77.3   76.6           1269.0
#
#        carbon_dioxide  nitrogen_dioxide  ammonia  methane  sulphur_dioxide  \
# 0                 NaN               NaN      NaN      NaN              NaN
# 1                 NaN               NaN      NaN      NaN              NaN
# 2                 NaN               NaN      NaN      NaN              NaN
# 3                 NaN               NaN      NaN      NaN              NaN
# 4                 NaN               NaN      NaN      NaN              NaN
# ...               ...               ...      ...      ...              ...
# 43867           451.0              58.9      NaN   1648.0             57.4
# 43868           452.0              54.7      NaN   1671.0             43.5
# 43869           456.0              51.5      NaN   1711.0             41.2
# 43870           464.0              50.8      NaN   1774.0             52.8
# 43871           476.0              51.1      NaN   1854.0             76.0
#
#        ozone
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 43867    6.0
# 43868    8.0
# 43869    9.0
# 43870    6.0
# 43871    2.0
#
# [43872 rows x 10 columns]

# %% [markdown]
# Delhi Analysis

# %%
delhi_df = pd.read_csv('/content/Delhi.csv')
print('\nDelhi Data:')
display(delhi_df.head())
# Out:
# Delhi Data:
#                         date  pm10  pm2_5  carbon_monoxide  carbon_dioxide  \
# 0  2020-01-01 00:00:00+00:00   NaN    NaN              NaN             NaN
# 1  2020-01-01 01:00:00+00:00   NaN    NaN              NaN             NaN
# 2  2020-01-01 02:00:00+00:00   NaN    NaN              NaN             NaN
# 3  2020-01-01 03:00:00+00:00   NaN    NaN              NaN             NaN
# 4  2020-01-01 04:00:00+00:00   NaN    NaN              NaN             NaN
#
#    nitrogen_dioxide  ammonia  methane  sulphur_dioxide  ozone
# 0               NaN      NaN      NaN              NaN    NaN
# 1               NaN      NaN      NaN              NaN    NaN
# 2               NaN      NaN      NaN              NaN    NaN
# 3               NaN      NaN      NaN              NaN    NaN
# 4               NaN      NaN      NaN              NaN    NaN

# %%
delhi_df
# Out:
#                             date   pm10  pm2_5  carbon_monoxide  \
# 0      2020-01-01 00:00:00+00:00    NaN    NaN              NaN
# 1      2020-01-01 01:00:00+00:00    NaN    NaN              NaN
# 2      2020-01-01 02:00:00+00:00    NaN    NaN              NaN
# 3      2020-01-01 03:00:00+00:00    NaN    NaN              NaN
# 4      2020-01-01 04:00:00+00:00    NaN    NaN              NaN
# ...                          ...    ...    ...              ...
# 43867  2025-01-01 19:00:00+00:00  170.4  167.6           1393.0
# 43868  2025-01-01 20:00:00+00:00  165.8  163.0           1328.0
# 43869  2025-01-01 21:00:00+00:00  160.7  157.9           1284.0
# 43870  2025-01-01 22:00:00+00:00  154.6  151.8           1274.0
# 43871  2025-01-01 23:00:00+00:00  149.5  146.7           1285.0
#
#        carbon_dioxide  nitrogen_dioxide  ammonia  methane  sulphur_dioxide  \
# 0                 NaN               NaN      NaN      NaN              NaN
# 1                 NaN               NaN      NaN      NaN              NaN
# 2                 NaN               NaN      NaN      NaN              NaN
# 3                 NaN               NaN      NaN      NaN              NaN
# 4                 NaN               NaN      NaN      NaN              NaN
# ...               ...               ...      ...      ...              ...
# 43867           442.0              35.3      NaN   1858.0             32.1
# 43868           440.0              27.3      NaN   1863.0             28.6
# 43869           439.0              21.0      NaN   1868.0             26.2
# 43870           440.0              17.0      NaN   1874.0             25.8
# 43871           442.0              14.6      NaN   1880.0             26.6
#
#        ozone
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 43867   45.0
# 43868   50.0
# 43869   54.0
# 43870   57.0
# 43871   61.0
#
# [43872 rows x 10 columns]

# %% [markdown]
# Dhaka Analysis

# %%
dhaka_df = pd.read_csv('/content/Dhaka.csv')
print('\nDhaka Data:')
display(dhaka_df.head())
# Out:
# Dhaka Data:
#                         date  pm10  pm2_5  carbon_monoxide  carbon_dioxide  \
# 0  2020-01-01 00:00:00+00:00   NaN    NaN              NaN             NaN
# 1  2020-01-01 01:00:00+00:00   NaN    NaN              NaN             NaN
# 2  2020-01-01 02:00:00+00:00   NaN    NaN              NaN             NaN
# 3  2020-01-01 03:00:00+00:00   NaN    NaN              NaN             NaN
# 4  2020-01-01 04:00:00+00:00   NaN    NaN              NaN             NaN
#
#    nitrogen_dioxide  ammonia  methane  sulphur_dioxide  ozone
# 0               NaN      NaN      NaN              NaN    NaN
# 1               NaN      NaN      NaN              NaN    NaN
# 2               NaN      NaN      NaN              NaN    NaN
# 3               NaN      NaN      NaN              NaN    NaN
# 4               NaN      NaN      NaN              NaN    NaN

# %%
dhaka_df
# Out:
#                             date  pm10  pm2_5  carbon_monoxide  \
# 0      2020-01-01 00:00:00+00:00   NaN    NaN              NaN
# 1      2020-01-01 01:00:00+00:00   NaN    NaN              NaN
# 2      2020-01-01 02:00:00+00:00   NaN    NaN              NaN
# 3      2020-01-01 03:00:00+00:00   NaN    NaN              NaN
# 4      2020-01-01 04:00:00+00:00   NaN    NaN              NaN
# ...                          ...   ...    ...              ...
# 43867  2025-01-01 19:00:00+00:00  94.5   93.4            904.0
# 43868  2025-01-01 20:00:00+00:00  92.2   91.3            830.0
# 43869  2025-01-01 21:00:00+00:00  90.3   89.4            776.0
# 43870  2025-01-01 22:00:00+00:00  88.9   88.0            762.0
# 43871  2025-01-01 23:00:00+00:00  88.0   87.3            768.0
#
#        carbon_dioxide  nitrogen_dioxide  ammonia  methane  sulphur_dioxide  \
# 0                 NaN               NaN      NaN      NaN              NaN
# 1                 NaN               NaN      NaN      NaN              NaN
# 2                 NaN               NaN      NaN      NaN              NaN
# 3                 NaN               NaN      NaN      NaN              NaN
# 4                 NaN               NaN      NaN      NaN              NaN
# ...               ...               ...      ...      ...              ...
# 43867           466.0              21.2      NaN   2147.0             11.9
# 43868           465.0              17.2      NaN   2113.0             11.6
# 43869           464.0              14.4      NaN   2084.0             11.6
# 43870           464.0              13.5      NaN   2070.0             11.8
# 43871           464.0              13.8      NaN   2061.0             12.2
#
#        ozone
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 43867   63.0
# 43868   64.0
# 43869   63.0
# 43870   60.0
# 43871   57.0
#
# [43872 rows x 10 columns]

# %% [markdown]
# Shanghai Analysis

# %%
shanghai_df = pd.read_csv('/content/Shanghai.csv')
print('\nShanghai Data:')
display(shanghai_df.head())
# Out:
# Shanghai Data:
#                         date  pm10  pm2_5  carbon_monoxide  carbon_dioxide  \
# 0  2020-01-01 00:00:00+00:00   NaN    NaN              NaN             NaN
# 1  2020-01-01 01:00:00+00:00   NaN    NaN              NaN             NaN
# 2  2020-01-01 02:00:00+00:00   NaN    NaN              NaN             NaN
# 3  2020-01-01 03:00:00+00:00   NaN    NaN              NaN             NaN
# 4  2020-01-01 04:00:00+00:00   NaN    NaN              NaN             NaN
#
#    nitrogen_dioxide  ammonia  methane  sulphur_dioxide  ozone
# 0               NaN      NaN      NaN              NaN    NaN
# 1               NaN      NaN      NaN              NaN    NaN
# 2               NaN      NaN      NaN              NaN    NaN
# 3               NaN      NaN      NaN              NaN    NaN
# 4               NaN      NaN      NaN              NaN    NaN

# %%
shanghai_df
# Out:
#                             date  pm10  pm2_5  carbon_monoxide  \
# 0      2020-01-01 00:00:00+00:00   NaN    NaN              NaN
# 1      2020-01-01 01:00:00+00:00   NaN    NaN              NaN
# 2      2020-01-01 02:00:00+00:00   NaN    NaN              NaN
# 3      2020-01-01 03:00:00+00:00   NaN    NaN              NaN
# 4      2020-01-01 04:00:00+00:00   NaN    NaN              NaN
# ...                          ...   ...    ...              ...
# 43867  2025-01-01 19:00:00+00:00  72.9   68.5            774.0
# 43868  2025-01-01 20:00:00+00:00  66.1   61.7            888.0
# 43869  2025-01-01 21:00:00+00:00  60.3   56.0           1158.0
# 43870  2025-01-01 22:00:00+00:00  60.5   56.2           1720.0
# 43871  2025-01-01 23:00:00+00:00  85.7   81.7           2440.0
#
#        carbon_dioxide  nitrogen_dioxide  ammonia  methane  sulphur_dioxide  \
# 0                 NaN               NaN      NaN      NaN              NaN
# 1                 NaN               NaN      NaN      NaN              NaN
# 2                 NaN               NaN      NaN      NaN              NaN
# 3                 NaN               NaN      NaN      NaN              NaN
# 4                 NaN               NaN      NaN      NaN              NaN
# ...               ...               ...      ...      ...              ...
# 43867           481.0              80.8      NaN   1796.0             15.3
# 43868           486.0              79.1      NaN   1827.0             13.3
# 43869           495.0              77.3      NaN   1873.0             15.2
# 43870           509.0              76.7      NaN   1947.0             25.3
# 43871           525.0              76.1      NaN   2037.0             39.3
#
#        ozone
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 43867    1.0
# 43868    2.0
# 43869    3.0
# 43870    2.0
# 43871    1.0
#
# [43872 rows x 10 columns]

# %% [markdown]
# Tokyo Analysis

# %%
tokyo_df = pd.read_csv('/content/Tokyo.csv')
print('\nTokyo Data:')
display(tokyo_df.head())
# Out:
# Tokyo Data:
#                         date  pm10  pm2_5  carbon_monoxide  carbon_dioxide  \
# 0  2020-01-01 00:00:00+00:00   NaN    NaN              NaN             NaN
# 1  2020-01-01 01:00:00+00:00   NaN    NaN              NaN             NaN
# 2  2020-01-01 02:00:00+00:00   NaN    NaN              NaN             NaN
# 3  2020-01-01 03:00:00+00:00   NaN    NaN              NaN             NaN
# 4  2020-01-01 04:00:00+00:00   NaN    NaN              NaN             NaN
#
#    nitrogen_dioxide  ammonia  methane  sulphur_dioxide  ozone
# 0               NaN      NaN      NaN              NaN    NaN
# 1               NaN      NaN      NaN              NaN    NaN
# 2               NaN      NaN      NaN              NaN    NaN
# 3               NaN      NaN      NaN              NaN    NaN
# 4               NaN      NaN      NaN              NaN    NaN

# %%
tokyo_df
# Out:
#                             date  pm10  pm2_5  carbon_monoxide  \
# 0      2020-01-01 00:00:00+00:00   NaN    NaN              NaN
# 1      2020-01-01 01:00:00+00:00   NaN    NaN              NaN
# 2      2020-01-01 02:00:00+00:00   NaN    NaN              NaN
# 3      2020-01-01 03:00:00+00:00   NaN    NaN              NaN
# 4      2020-01-01 04:00:00+00:00   NaN    NaN              NaN
# ...                          ...   ...    ...              ...
# 43867  2025-01-01 19:00:00+00:00  41.6   41.1            512.0
# 43868  2025-01-01 20:00:00+00:00  42.5   42.0            494.0
# 43869  2025-01-01 21:00:00+00:00  51.8   51.3            493.0
# 43870  2025-01-01 22:00:00+00:00  70.3   69.8            508.0
# 43871  2025-01-01 23:00:00+00:00  84.1   83.6            540.0
#
#        carbon_dioxide  nitrogen_dioxide  ammonia  methane  sulphur_dioxide  \
# 0                 NaN               NaN      NaN      NaN              NaN
# 1                 NaN               NaN      NaN      NaN              NaN
# 2                 NaN               NaN      NaN      NaN              NaN
# 3                 NaN               NaN      NaN      NaN              NaN
# 4                 NaN               NaN      NaN      NaN              NaN
# ...               ...               ...      ...      ...              ...
# 43867           494.0              75.7      NaN   1516.0             60.1
# 43868           495.0              73.3      NaN   1507.0             64.0
# 43869           499.0              70.8      NaN   1500.0             71.1
# 43870           505.0              68.7      NaN   1494.0             86.9
# 43871           514.0              66.5      NaN   1490.0            105.9
#
#        ozone
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 43867    0.0
# 43868    0.0
# 43869    0.0
# 43870    1.0
# 43871    2.0
#
# [43872 rows x 10 columns]

# %% [markdown]
# Beijing Cleaning

# %%
import pandas as pd
import numpy as np

fn = "Beijing.csv"
df = pd.read_csv(fn)

print("shape:", df.shape)
print("columns:", df.columns.tolist())
print(df.head(5))
print("\nmissing per column:\n", df.isna().sum())
# Out:
# shape: (43872, 10)
# columns: ['date', 'pm10', 'pm2_5', 'carbon_monoxide', 'carbon_dioxide', 'nitrogen_dioxide', 'ammonia', 'methane', 'sulphur_dioxide', 'ozone']
#                         date  pm10  pm2_5  carbon_monoxide  carbon_dioxide  \
# 0  2020-01-01 00:00:00+00:00   NaN    NaN              NaN             NaN
# 1  2020-01-01 01:00:00+00:00   NaN    NaN              NaN             NaN
# 2  2020-01-01 02:00:00+00:00   NaN    NaN              NaN             NaN
# 3  2020-01-01 03:00:00+00:00   NaN    NaN              NaN             NaN
# 4  2020-01-01 04:00:00+00:00   NaN    NaN              NaN             NaN
#
#    nitrogen_dioxide  ammonia  methane  sulphur_dioxide  ozone
# 0               NaN      NaN      NaN              NaN    NaN
# 1               NaN      NaN      NaN              NaN    NaN
# 2               NaN      NaN      NaN              NaN    NaN
# 3               NaN      NaN      NaN              NaN    NaN
# 4               NaN      NaN      NaN              NaN    NaN
#
# missing per column:
#  date                    0
# pm10                22704
# pm2_5               22704
# carbon_monoxide     22704
# carbon_dioxide      42240
# nitrogen_dioxide    22704
# ammonia             43872
# methane             42240
# sulphur_dioxide     22704
# ozone               22704
# dtype: int64

# %%
df.columns = (
    df.columns.str.strip()
              .str.lower()
              .str.replace(" ", "_")
              .str.replace("-", "_")
)

print(df.columns.tolist())
# Out:
# ['date', 'pm10', 'pm2_5', 'carbon_monoxide', 'carbon_dioxide', 'nitrogen_dioxide', 'ammonia', 'methane', 'sulphur_dioxide', 'ozone']

# %%
candidates = ["datetime", "date_time", "date", "time", "timestamp"]
dt_col = None

for c in candidates:
    if c in df.columns:
        dt_col = c
        break

if dt_col is None:
    raise RuntimeError("No datetime column found. Rename your column to one of: " + ", ".join(candidates))

df["datetime"] = pd.to_datetime(df[dt_col], errors="coerce")
print("Parsed datetime:", dt_col, " — nulls:", df["datetime"].isna().sum())

df = df[~df["datetime"].isna()].copy()
df = df.sort_values("datetime").reset_index(drop=True)

print("After datetime cleaning, rows:", len(df))
# Out:
# Parsed datetime: date  — nulls: 0
# After datetime cleaning, rows: 43872

# %%
pollutants = [
    "pm10","pm2_5","ammonia",
    "carbon_monoxide","nitrogen_dioxide",
    "carbon_dioxide","sulphur_dioxide","methane"
]

# try to fix common alternative column names
col_map = {}
for p in pollutants:
    if p not in df.columns:
        alternatives = [
            p.replace("_",""),
            p.replace("2_5","2.5"),
            p.replace("pm2_5","pm2.5"),
            p.replace("pm2_5","pm25"),
        ]
        for alt in alternatives:
            if alt in df.columns:
                col_map[alt] = p

if col_map:
    df = df.rename(columns=col_map)
    print("Renamed columns:", col_map)

missing = [p for p in pollutants if p not in df.columns]
if missing:
    print("Warning: Missing pollutant columns:", missing)

# convert to numeric
for p in pollutants:
    if p in df.columns:
        df[p] = (
            df[p].astype(str)
                 .str.replace("<","")
                 .str.replace(",","")
                 .str.strip()
        )
        df[p] = pd.to_numeric(df[p], errors="coerce")

# %%
# negative values → NaN
for p in pollutants:
    if p in df.columns:
        df.loc[df[p] < 0, p] = np.nan

# cap at 99.9 percentile (pollutant-dependent)
for p in pollutants:
    if p in df.columns:
        q = df[p].quantile(0.999)
        if pd.notna(q) and q > 0:
            df.loc[df[p] > q, p] = np.nan
        print(f"{p}: capped at {q}")
# Out:
# pm10: capped at 562.5
# pm2_5: capped at 392.84970000000214
# ammonia: capped at nan
# carbon_monoxide: capped at 9729.165000000012
# nitrogen_dioxide: capped at 260.608050000002
# carbon_dioxide: capped at 819.7380000000003
# sulphur_dioxide: capped at 371.3487000000092
# methane: capped at 5690.0840000000335

# %%
df = df.set_index("datetime")

start = df.index.min().ceil("H")
end   = df.index.max().floor("H")

full_idx = pd.date_range(start=start, end=end, freq="H")

df = df.reindex(full_idx)
print("Reindexed to hourly:", len(df))
# Out:
# Reindexed to hourly: 43872
# /tmp/ipython-input-1351569827.py:3: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   start = df.index.min().ceil("H")
# /tmp/ipython-input-1351569827.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   end   = df.index.max().floor("H")
# /tmp/ipython-input-1351569827.py:6: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   full_idx = pd.date_range(start=start, end=end, freq="H")

# %%
numeric_cols = [c for c in pollutants if c in df.columns]

df[numeric_cols] = df[numeric_cols].interpolate(method="time", limit=24)
df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

print("Remaining NaNs:\n", df[numeric_cols].isna().sum())
# Out:
# Remaining NaNs:
#  pm10                22698
# pm2_5               22698
# ammonia             43872
# carbon_monoxide     22698
# nitrogen_dioxide    22698
# carbon_dioxide      42234
# sulphur_dioxide     22698
# methane             42234
# dtype: int64
# /tmp/ipython-input-774743577.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

# %%
df["missing_pollutants"] = df[numeric_cols].isna().sum(axis=1)

summary = df[numeric_cols].describe().T
summary["missing"] = df[numeric_cols].isna().sum()

summary
# Out:
#                     count         mean          std     min      25%     50%  \
# pm10              21174.0   108.341138    79.147096     0.7    53.90    92.2
# pm2_5             21174.0    75.294366    57.725007     0.5    35.00    63.0
# ammonia               0.0          NaN          NaN     NaN      NaN     NaN
# carbon_monoxide   21174.0  1302.999126  1364.751171     0.0   473.00   815.0
# nitrogen_dioxide  21174.0    62.544712    36.017537     0.0    39.60    57.2
# carbon_dioxide     1638.0   528.908425    68.620196   438.0   474.00   517.0
# sulphur_dioxide   21174.0    66.882944    55.859895     0.0    28.90    50.6
# methane            1638.0  2379.612332   789.652445  1385.0  1764.25  2172.0
#
#                      75%     max  missing
# pm10               141.1   562.5    22698
# pm2_5               98.5   392.1    22698
# ammonia              NaN     NaN    43872
# carbon_monoxide   1584.0  9725.0    22698
# nitrogen_dioxide    78.1   259.9    22698
# carbon_dioxide     565.0   819.0    42234
# sulphur_dioxide     87.6   368.1    22698
# methane           2843.5  5603.0    42234

# %%
means = df[numeric_cols].mean(skipna=True) # may contain NaN for pollutant with no valid data
ranking = means.reset_index()
ranking.columns = ["pollutant", "mean_value"]

# Split valid (finite means) and invalid (NaN means)
valid = ranking[ranking["mean_value"].notna()].copy()
invalid = ranking[ranking["mean_value"].isna()].copy()

# Rank only the valid ones (descending); convert to int safely
valid["rank"] = valid["mean_value"].rank(method="min", ascending=False).astype(int)

# For invalid ones, set rank to pandas NA (nullable Int)
import pandas as pd
invalid["rank"] = pd.NA

# Combine back, put valid ranked items first
final_ranking = pd.concat([valid, invalid], ignore_index=True)
final_ranking = final_ranking.sort_values(by=["rank", "pollutant"], na_position="last").reset_index(drop=True)

print(final_ranking)

# Save cleaned hourly file and ranking
df.reset_index().rename(columns={"index":"datetime"}).to_csv("Beijing_clean_hourly.csv", index=False)
final_ranking.to_csv("Beijing_pollutant_ranking.csv", index=False)

print("Saved: Beijing_clean_hourly.csv and Beijing_pollutant_ranking.csv")
# Out:
#           pollutant   mean_value  rank
# 0           methane  2379.612332     1
# 1   carbon_monoxide  1302.999126     2
# 2    carbon_dioxide   528.908425     3
# 3              pm10   108.341138     4
# 4             pm2_5    75.294366     5
# 5   sulphur_dioxide    66.882944     6
# 6  nitrogen_dioxide    62.544712     7
# 7           ammonia          NaN  <NA>
# Saved: Beijing_clean_hourly.csv and Beijing_pollutant_ranking.csv

# %% [markdown]
# Delhi Cleaning

# %%
import pandas as pd
import numpy as np

fn = "Delhi.csv"
df = pd.read_csv(fn)

print("shape:", df.shape)
print("columns:", df.columns.tolist())
print(df.head(5))
print("\nMissing per column:\n", df.isna().sum())
# Out:
# shape: (43872, 10)
# columns: ['date', 'pm10', 'pm2_5', 'carbon_monoxide', 'carbon_dioxide', 'nitrogen_dioxide', 'ammonia', 'methane', 'sulphur_dioxide', 'ozone']
#                         date  pm10  pm2_5  carbon_monoxide  carbon_dioxide  \
# 0  2020-01-01 00:00:00+00:00   NaN    NaN              NaN             NaN
# 1  2020-01-01 01:00:00+00:00   NaN    NaN              NaN             NaN
# 2  2020-01-01 02:00:00+00:00   NaN    NaN              NaN             NaN
# 3  2020-01-01 03:00:00+00:00   NaN    NaN              NaN             NaN
# 4  2020-01-01 04:00:00+00:00   NaN    NaN              NaN             NaN
#
#    nitrogen_dioxide  ammonia  methane  sulphur_dioxide  ozone
# 0               NaN      NaN      NaN              NaN    NaN
# 1               NaN      NaN      NaN              NaN    NaN
# 2               NaN      NaN      NaN              NaN    NaN
# 3               NaN      NaN      NaN              NaN    NaN
# 4               NaN      NaN      NaN              NaN    NaN
#
# Missing per column:
#  date                    0
# pm10                22704
# pm2_5               22704
# carbon_monoxide     22704
# carbon_dioxide      42240
# nitrogen_dioxide    22704
# ammonia             43872
# methane             42240
# sulphur_dioxide     22704
# ozone               22704
# dtype: int64

# %%
df.columns = (
    df.columns.str.strip()
              .str.lower()
              .str.replace(" ", "_", regex=False)
              .str.replace("-", "_", regex=False)
)

print(df.columns.tolist())
# Out:
# ['date', 'pm10', 'pm2_5', 'carbon_monoxide', 'carbon_dioxide', 'nitrogen_dioxide', 'ammonia', 'methane', 'sulphur_dioxide', 'ozone']

# %%
candidates = ["datetime", "date_time", "date", "time", "timestamp"]
dt_col = next((c for c in candidates if c in df.columns), None)

if dt_col is None:
    raise RuntimeError("No datetime column found. Rename your date/time column to one of: " + ", ".join(candidates))

df["datetime"] = pd.to_datetime(df[dt_col], errors="coerce")
print(f"Parsed datetime column: '{dt_col}' — null after parse = {df['datetime'].isna().sum()}")

df = df.dropna(subset=["datetime"]).copy()
df = df.sort_values("datetime").reset_index(drop=True)
print("Rows after datetime cleaning:", len(df))
# Out:
# Parsed datetime column: 'date' — null after parse = 0
# Rows after datetime cleaning: 43872

# %%
pollutants = [
    "pm10","pm2_5","ammonia","carbon_monoxide",
    "nitrogen_dioxide","carbon_dioxide","sulphur_dioxide","methane"
]

# map common variants (pm2.5, pm25, etc.) to pm2_5
col_map = {}
for p in pollutants:
    if p not in df.columns:
        alternatives = [
            p.replace("_",""),
            p.replace("2_5","2.5"),
            p.replace("pm2_5","pm2.5"),
            "pm25","pm2.5"
        ]
        for alt in alternatives:
            if alt in df.columns:
                col_map[alt] = p

if col_map:
    df = df.rename(columns=col_map)
    print("Renamed columns:", col_map)

missing = [p for p in pollutants if p not in df.columns]
if missing:
    print("Warning — missing pollutant columns:", missing)

# convert to numeric and clean strings like "<1" or "1,234"
for p in pollutants:
    if p in df.columns:
        df[p] = (
            df[p].astype(str)
                 .str.replace("<", "", regex=False)
                 .str.replace(",", "", regex=False)
                 .str.strip()
        )
        df[p] = pd.to_numeric(df[p], errors="coerce")

# %%
for p in pollutants:
    if p in df.columns:
        df.loc[df[p] < 0, p] = np.nan

for p in pollutants:
    if p in df.columns:
        q = df[p].quantile(0.999)
        if pd.notna(q) and q > 0:
            df.loc[df[p] > q, p] = np.nan
        print(f"{p}: 99.9% cap = {q}")
# Out:
# pm10: 99.9% cap = 476.8
# pm2_5: 99.9% cap = 283.9330000000024
# ammonia: 99.9% cap = nan
# carbon_monoxide: 99.9% cap = 8799.45900000029
# nitrogen_dioxide: 99.9% cap = 208.68300000000235
# carbon_dioxide: 99.9% cap = 582.0
# sulphur_dioxide: 99.9% cap = 287.1326000000052
# methane: 99.9% cap = 2217.0590000000016

# %%
df = df.set_index("datetime")

start = df.index.min().ceil("H")
end   = df.index.max().floor("H")

full_idx = pd.date_range(start=start, end=end, freq="H")

df = df.reindex(full_idx)
print("Reindexed hourly — new length:", len(df))
# Out:
# Reindexed hourly — new length: 43872
# /tmp/ipython-input-2946176890.py:3: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   start = df.index.min().ceil("H")
# /tmp/ipython-input-2946176890.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   end   = df.index.max().floor("H")
# /tmp/ipython-input-2946176890.py:6: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   full_idx = pd.date_range(start=start, end=end, freq="H")

# %%
numeric_cols = [c for c in pollutants if c in df.columns]

df[numeric_cols] = df[numeric_cols].interpolate(method="time", limit=24)
df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

print("Remaining NaNs per pollutant:\n", df[numeric_cols].isna().sum())
# Out:
# Remaining NaNs per pollutant:
#  pm10                22698
# pm2_5               22698
# ammonia             43872
# carbon_monoxide     22698
# nitrogen_dioxide    22698
# carbon_dioxide      42234
# sulphur_dioxide     22698
# methane             42234
# dtype: int64
# /tmp/ipython-input-1757015156.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

# %%
df["n_missing_pollutants"] = df[numeric_cols].isna().sum(axis=1)
summary = df[numeric_cols].describe().T
summary["missing_count"] = df[numeric_cols].isna().sum()
summary
# Out:
#                     count         mean          std     min     25%     50%  \
# pm10              21174.0   118.459887    69.583025     0.2    68.0   103.1
# pm2_5             21174.0    68.909240    43.738978     0.2    38.5    56.5
# ammonia               0.0          NaN          NaN     NaN     NaN     NaN
# carbon_monoxide   21174.0  1069.667564  1010.138819    59.0   440.0   740.0
# nitrogen_dioxide  21174.0    46.020609    34.526723     0.0    19.5    37.6
# carbon_dioxide     1638.0   473.523810    30.174453   435.0   453.0   463.0
# sulphur_dioxide   21174.0    41.151593    32.961446     0.2    20.9    31.4
# methane            1638.0  1653.462149   136.375364  1401.0  1548.0  1629.5
#
#                      75%      max  missing_count
# pm10               152.7   476.80          22698
# pm2_5               86.8   283.10          22698
# ammonia              NaN      NaN          43872
# carbon_monoxide   1327.0  8697.00          22698
# nitrogen_dioxide    64.6   207.85          22698
# carbon_dioxide     484.0   582.00          42234
# sulphur_dioxide     48.8   285.30          22698
# methane           1737.0  2213.00          42234

# %%
means = df[numeric_cols].mean(skipna=True)
ranking = means.reset_index()
ranking.columns = ["pollutant", "mean_value"]

# separate valid and invalid means
valid = ranking[ranking["mean_value"].notna()].copy()
invalid = ranking[ranking["mean_value"].isna()].copy()

valid["rank"] = valid["mean_value"].rank(method="min", ascending=False).astype(int)
invalid["rank"] = pd.NA

final_ranking = pd.concat([valid, invalid], ignore_index=True)
final_ranking = final_ranking.sort_values(["rank","pollutant"], na_position="last").reset_index(drop=True)

print(final_ranking)

# Save cleaned hourly and ranking
df.reset_index().rename(columns={"index":"datetime"}).to_csv("Delhi_clean_hourly.csv", index=False)
final_ranking.to_csv("Delhi_pollutant_ranking.csv", index=False)

print("Saved: Delhi_clean_hourly.csv and Delhi_pollutant_ranking.csv")
# Out:
#           pollutant   mean_value  rank
# 0           methane  1653.462149     1
# 1   carbon_monoxide  1069.667564     2
# 2    carbon_dioxide   473.523810     3
# 3              pm10   118.459887     4
# 4             pm2_5    68.909240     5
# 5  nitrogen_dioxide    46.020609     6
# 6   sulphur_dioxide    41.151593     7
# 7           ammonia          NaN  <NA>
# Saved: Delhi_clean_hourly.csv and Delhi_pollutant_ranking.csv

# %% [markdown]
# Dhaka Cleaning

# %%
import pandas as pd
import numpy as np

# file name
fn = "Dhaka.csv"

df = pd.read_csv(fn)

print("shape:", df.shape)
print("columns:", df.columns.tolist())
print(df.head())
print("\nmissing per column:\n", df.isna().sum())
# Out:
# shape: (43872, 10)
# columns: ['date', 'pm10', 'pm2_5', 'carbon_monoxide', 'carbon_dioxide', 'nitrogen_dioxide', 'ammonia', 'methane', 'sulphur_dioxide', 'ozone']
#                         date  pm10  pm2_5  carbon_monoxide  carbon_dioxide  \
# 0  2020-01-01 00:00:00+00:00   NaN    NaN              NaN             NaN
# 1  2020-01-01 01:00:00+00:00   NaN    NaN              NaN             NaN
# 2  2020-01-01 02:00:00+00:00   NaN    NaN              NaN             NaN
# 3  2020-01-01 03:00:00+00:00   NaN    NaN              NaN             NaN
# 4  2020-01-01 04:00:00+00:00   NaN    NaN              NaN             NaN
#
#    nitrogen_dioxide  ammonia  methane  sulphur_dioxide  ozone
# 0               NaN      NaN      NaN              NaN    NaN
# 1               NaN      NaN      NaN              NaN    NaN
# 2               NaN      NaN      NaN              NaN    NaN
# 3               NaN      NaN      NaN              NaN    NaN
# 4               NaN      NaN      NaN              NaN    NaN
#
# missing per column:
#  date                    0
# pm10                22704
# pm2_5               22704
# carbon_monoxide     22704
# carbon_dioxide      42240
# nitrogen_dioxide    22704
# ammonia             43872
# methane             42240
# sulphur_dioxide     22704
# ozone               22704
# dtype: int64

# %%
df.columns = (
    df.columns.str.strip()
    .str.lower()
    .str.replace(" ", "_")
    .str.replace("-", "_")
)

print(df.columns.tolist())
# Out:
# ['date', 'pm10', 'pm2_5', 'carbon_monoxide', 'carbon_dioxide', 'nitrogen_dioxide', 'ammonia', 'methane', 'sulphur_dioxide', 'ozone']

# %%
candidates = ["datetime", "date_time", "date", "time", "timestamp"]

dt_col = None
for c in candidates:
    if c in df.columns:
        dt_col = c
        break

if dt_col is None:
    raise RuntimeError("No datetime column found. Rename your date column to datetime/date/date_time/etc.")

df["datetime"] = pd.to_datetime(df[dt_col], errors="coerce")

null_count = df["datetime"].isna().sum()
print(f"Parsed datetime column: '{dt_col}', null after parse = {null_count}")

df = df.dropna(subset=["datetime"]).copy()
df = df.sort_values("datetime").reset_index(drop=True)
# Out:
# Parsed datetime column: 'date', null after parse = 0

# %%
pollutants = [
    "pm10","pm2_5","ammonia","carbon_monoxide","nitrogen_dioxide",
    "carbon_dioxide","sulphur_dioxide","methane"
]

# attempt fixes for alternate names
col_map = {}
for p in pollutants:
    if p not in df.columns:
        alt = p.replace("_","").replace("2_5","2.5").replace("pm2_5","pm2.5")
        for candidate in [alt, alt.replace(".","_"), alt.replace(".","")]:
            if candidate in df.columns:
                col_map[candidate] = p

if col_map:
    df = df.rename(columns=col_map)
    print("Renamed:", col_map)

missing_cols = [p for p in pollutants if p not in df.columns]
if missing_cols:
    print("Missing pollutant columns:", missing_cols)

# convert to numeric
for p in pollutants:
    if p in df.columns:
        df[p] = (
            df[p].astype(str)
                 .str.replace("<","")
                 .str.replace(",","")
                 .str.strip()
        )
        df[p] = pd.to_numeric(df[p], errors="coerce")

# %%
for p in pollutants:
    if p in df.columns:
        df.loc[df[p] < 0, p] = np.nan

for p in pollutants:
    if p in df.columns:
        q = df[p].quantile(0.999)
        if pd.notna(q) and q > 0:
            df.loc[df[p] > q, p] = np.nan
        print(f"{p} cap at 99.9% =", q)
# Out:
# pm10 cap at 99.9% = 346.7821000000087
# pm2_5 cap at 99.9% = 242.6324000000066
# ammonia cap at 99.9% = nan
# carbon_monoxide cap at 99.9% = 3906.662000000033
# nitrogen_dioxide cap at 99.9% = 153.54145000000153
# carbon_dioxide cap at 99.9% = 614.3690000000001
# sulphur_dioxide cap at 99.9% = 53.00825000000059
# methane cap at 99.9% = 5368.906000000067

# %%
df = df.set_index("datetime")

start = df.index.min().ceil("H")
end   = df.index.max().floor("H")

full_idx = pd.date_range(start=start, end=end, freq="H")

df = df.reindex(full_idx)
print("Hourly reindex length:", len(df))
# Out:
# Hourly reindex length: 43872
# /tmp/ipython-input-2271776757.py:3: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   start = df.index.min().ceil("H")
# /tmp/ipython-input-2271776757.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   end   = df.index.max().floor("H")
# /tmp/ipython-input-2271776757.py:6: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   full_idx = pd.date_range(start=start, end=end, freq="H")

# %%
numeric_cols = [c for c in pollutants if c in df.columns]

df[numeric_cols] = df[numeric_cols].interpolate(method="time", limit=24)
df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

print("Remaining NaNs:\n", df[numeric_cols].isna().sum())
# Out:
# Remaining NaNs:
#  pm10                22698
# pm2_5               22698
# ammonia             43872
# carbon_monoxide     22698
# nitrogen_dioxide    22698
# carbon_dioxide      42234
# sulphur_dioxide     22698
# methane             42234
# dtype: int64
# /tmp/ipython-input-774743577.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

# %%
df["n_missing_pollutants"] = df[numeric_cols].isna().sum(axis=1)
df[numeric_cols].describe().T
# Out:
#                     count         mean         std      min     25%     50%  \
# pm10              21174.0    70.797823   50.440394     0.60    29.9    61.2
# pm2_5             21174.0    48.976398   35.872315     0.40    19.8    41.3
# ammonia               0.0          NaN         NaN      NaN     NaN     NaN
# carbon_monoxide   21174.0   619.268726  526.330408    58.00   263.0   442.0
# nitrogen_dioxide  21174.0    36.492148   31.401218     0.00    12.9    24.0
# carbon_dioxide     1638.0   466.781441   25.971288   434.00   450.0   460.0
# sulphur_dioxide   21174.0    12.906757    7.965358     0.25     6.8    11.0
# methane            1638.0  2353.919414  689.507515  1429.00  1796.0  2222.5
#
#                         75%     max
# pm10                99.7000   343.7
# pm2_5               69.4000   240.3
# ammonia                 NaN     NaN
# carbon_monoxide    793.0000  3895.0
# nitrogen_dioxide    52.0000   153.0
# carbon_dioxide     473.0000   614.0
# sulphur_dioxide     17.1375    52.8
# methane           2719.0000  5194.0

# %%
means = df[numeric_cols].mean(skipna=True)

ranking = means.reset_index()
ranking.columns = ["pollutant", "mean_value"]

valid = ranking[ranking["mean_value"].notna()].copy()
invalid = ranking[ranking["mean_value"].isna()].copy()

valid["rank"] = valid["mean_value"].rank(method="min", ascending=False).astype(int)
invalid["rank"] = pd.NA

final_ranking = pd.concat([valid, invalid], ignore_index=True)
final_ranking = final_ranking.sort_values(["rank", "pollutant"], na_position="last").reset_index(drop=True)

print(final_ranking)

df.reset_index().rename(columns={"index":"datetime"}).to_csv("Dhaka_clean_hourly.csv", index=False)
final_ranking.to_csv("Dhaka_pollutant_ranking.csv", index=False)

print("Saved: Dhaka_clean_hourly.csv & Dhaka_pollutant_ranking.csv")
# Out:
#           pollutant   mean_value  rank
# 0           methane  2353.919414     1
# 1   carbon_monoxide   619.268726     2
# 2    carbon_dioxide   466.781441     3
# 3              pm10    70.797823     4
# 4             pm2_5    48.976398     5
# 5  nitrogen_dioxide    36.492148     6
# 6   sulphur_dioxide    12.906757     7
# 7           ammonia          NaN  <NA>
# Saved: Dhaka_clean_hourly.csv & Dhaka_pollutant_ranking.csv

# %% [markdown]
# Shanghai Cleaning

# %%
import pandas as pd
import numpy as np

fn = "Shanghai.csv"
df = pd.read_csv(fn)

print("shape:", df.shape)
print("columns:", df.columns.tolist())
print(df.head(5))
print("\nMissing per column:\n", df.isna().sum())
# Out:
# shape: (43872, 10)
# columns: ['date', 'pm10', 'pm2_5', 'carbon_monoxide', 'carbon_dioxide', 'nitrogen_dioxide', 'ammonia', 'methane', 'sulphur_dioxide', 'ozone']
#                         date  pm10  pm2_5  carbon_monoxide  carbon_dioxide  \
# 0  2020-01-01 00:00:00+00:00   NaN    NaN              NaN             NaN
# 1  2020-01-01 01:00:00+00:00   NaN    NaN              NaN             NaN
# 2  2020-01-01 02:00:00+00:00   NaN    NaN              NaN             NaN
# 3  2020-01-01 03:00:00+00:00   NaN    NaN              NaN             NaN
# 4  2020-01-01 04:00:00+00:00   NaN    NaN              NaN             NaN
#
#    nitrogen_dioxide  ammonia  methane  sulphur_dioxide  ozone
# 0               NaN      NaN      NaN              NaN    NaN
# 1               NaN      NaN      NaN              NaN    NaN
# 2               NaN      NaN      NaN              NaN    NaN
# 3               NaN      NaN      NaN              NaN    NaN
# 4               NaN      NaN      NaN              NaN    NaN
#
# Missing per column:
#  date                    0
# pm10                22704
# pm2_5               22704
# carbon_monoxide     22704
# carbon_dioxide      42240
# nitrogen_dioxide    22704
# ammonia             43872
# methane             42240
# sulphur_dioxide     22704
# ozone               22704
# dtype: int64

# %%
df.columns = (
    df.columns.str.strip()
              .str.lower()
              .str.replace(" ", "_", regex=False)
              .str.replace("-", "_", regex=False)
)

print(df.columns.tolist())
# Out:
# ['date', 'pm10', 'pm2_5', 'carbon_monoxide', 'carbon_dioxide', 'nitrogen_dioxide', 'ammonia', 'methane', 'sulphur_dioxide', 'ozone']

# %%
candidates = ["datetime", "date_time", "date", "time", "timestamp"]
dt_col = next((c for c in candidates if c in df.columns), None)

if dt_col is None:
    raise RuntimeError("No datetime column found. Rename your date/time column to one of: " + ", ".join(candidates))

df["datetime"] = pd.to_datetime(df[dt_col], errors="coerce")
print(f"Parsed datetime column: '{dt_col}' — null after parse = {df['datetime'].isna().sum()}")

df = df.dropna(subset=["datetime"]).copy()
df = df.sort_values("datetime").reset_index(drop=True)
print("Rows after datetime cleaning:", len(df))
# Out:
# Parsed datetime column: 'date' — null after parse = 0
# Rows after datetime cleaning: 43872

# %%
pollutants = [
    "pm10","pm2_5","ammonia","carbon_monoxide",
    "nitrogen_dioxide","carbon_dioxide","sulphur_dioxide","methane"
]

# map common variants (pm2.5, pm25, etc.) to pm2_5
col_map = {}
for p in pollutants:
    if p not in df.columns:
        alternatives = [
            p.replace("_",""),
            p.replace("2_5","2.5"),
            p.replace("pm2_5","pm2.5"),
            "pm25","pm2.5"
        ]
        for alt in alternatives:
            if alt in df.columns:
                col_map[alt] = p

if col_map:
    df = df.rename(columns=col_map)
    print("Renamed columns:", col_map)

missing = [p for p in pollutants if p not in df.columns]
if missing:
    print("Warning — missing pollutant columns:", missing)

# convert to numeric and clean strings like "<1" or "1,234"
for p in pollutants:
    if p in df.columns:
        df[p] = (
            df[p].astype(str)
                 .str.replace("<", "", regex=False)
                 .str.replace(",", "", regex=False)
                 .str.strip()
        )
        df[p] = pd.to_numeric(df[p], errors="coerce")

# %%
for p in pollutants:
    if p in df.columns:
        df.loc[df[p] < 0, p] = np.nan

for p in pollutants:
    if p in df.columns:
        q = df[p].quantile(0.999)
        if pd.notna(q) and q > 0:
            df.loc[df[p] > q, p] = np.nan
        print(f"{p}: 99.9% cap = {q}")
# Out:
# pm10: 99.9% cap = 536.4
# pm2_5: 99.9% cap = 374.4
# ammonia: 99.9% cap = nan
# carbon_monoxide: 99.9% cap = 15470.783000000356
# nitrogen_dioxide: 99.9% cap = 198.48320000000095
# carbon_dioxide: 99.9% cap = 774.1070000000004
# sulphur_dioxide: 99.9% cap = 505.5813000000144
# methane: 99.9% cap = 3203.0180000000173

# %%
df = df.set_index("datetime")

start = df.index.min().ceil("H")
end   = df.index.max().floor("H")

full_idx = pd.date_range(start=start, end=end, freq="H")

df = df.reindex(full_idx)
print("Reindexed hourly — new length:", len(df))
# Out:
# Reindexed hourly — new length: 43872
# /tmp/ipython-input-2946176890.py:3: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   start = df.index.min().ceil("H")
# /tmp/ipython-input-2946176890.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   end   = df.index.max().floor("H")
# /tmp/ipython-input-2946176890.py:6: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   full_idx = pd.date_range(start=start, end=end, freq="H")

# %%
numeric_cols = [c for c in pollutants if c in df.columns]

df[numeric_cols] = df[numeric_cols].interpolate(method="time", limit=24)
df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

print("Remaining NaNs per pollutant:\n", df[numeric_cols].isna().sum())
# Out:
# Remaining NaNs per pollutant:
#  pm10                22698
# pm2_5               22698
# ammonia             43872
# carbon_monoxide     22698
# nitrogen_dioxide    22698
# carbon_dioxide      42234
# sulphur_dioxide     22698
# methane             42234
# dtype: int64
# /tmp/ipython-input-1757015156.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

# %%
df["n_missing_pollutants"] = df[numeric_cols].isna().sum(axis=1)
summary = df[numeric_cols].describe().T
summary["missing_count"] = df[numeric_cols].isna().sum()
summary
# Out:
#                     count         mean          std     min     25%     50%  \
# pm10              21174.0    69.138963    59.260500     0.7    32.6    50.6
# pm2_5             21174.0    46.537692    42.789233     0.5    20.1    32.6
# ammonia               0.0          NaN          NaN     NaN     NaN     NaN
# carbon_monoxide   21174.0  1055.324785  1436.217716     0.0   242.0   487.0
# nitrogen_dioxide  21174.0    63.593974    28.102776     0.0    43.3    62.7
# carbon_dioxide     1638.0   512.164835    57.172533   442.0   470.0   496.0
# sulphur_dioxide   21174.0    60.725479    65.696183     0.0    15.7    37.5
# methane            1638.0  1734.468254   304.631672  1363.0  1522.0  1649.0
#
#                       75%       max  missing_count
# pm10                83.80    536.40          22698
# pm2_5               56.30    374.40          22698
# ammonia               NaN       NaN          43872
# carbon_monoxide   1254.75  15345.00          22698
# nitrogen_dioxide    80.45    198.15          22698
# carbon_dioxide     536.75    773.00          42234
# sulphur_dioxide     81.10    500.50          22698
# methane           1846.00   3158.00          42234

# %%
means = df[numeric_cols].mean(skipna=True)
ranking = means.reset_index()
ranking.columns = ["pollutant", "mean_value"]

# separate valid and invalid means
valid = ranking[ranking["mean_value"].notna()].copy()
invalid = ranking[ranking["mean_value"].isna()].copy()

valid["rank"] = valid["mean_value"].rank(method="min", ascending=False).astype(int)
invalid["rank"] = pd.NA

final_ranking = pd.concat([valid, invalid], ignore_index=True)
final_ranking = final_ranking.sort_values(["rank","pollutant"], na_position="last").reset_index(drop=True)

print(final_ranking)

# Save cleaned hourly and ranking
df.reset_index().rename(columns={"index":"datetime"}).to_csv("Shanghai_clean_hourly.csv", index=False)
final_ranking.to_csv("Shanghai_pollutant_ranking.csv", index=False)

print("Saved: Shanghai_clean_hourly.csv and Shanghai_pollutant_ranking.csv")
# Out:
#           pollutant   mean_value  rank
# 0           methane  1734.468254     1
# 1   carbon_monoxide  1055.324785     2
# 2    carbon_dioxide   512.164835     3
# 3              pm10    69.138963     4
# 4  nitrogen_dioxide    63.593974     5
# 5   sulphur_dioxide    60.725479     6
# 6             pm2_5    46.537692     7
# 7           ammonia          NaN  <NA>
# Saved: Shanghai_clean_hourly.csv and Shanghai_pollutant_ranking.csv

# %% [markdown]
# Tokyo Cleaning

# %%
import pandas as pd
import numpy as np

fn = "Tokyo.csv"
df = pd.read_csv(fn)

print("shape:", df.shape)
print("columns:", df.columns.tolist())
print(df.head(5))
print("\nMissing per column:\n", df.isna().sum())
# Out:
# shape: (43872, 10)
# columns: ['date', 'pm10', 'pm2_5', 'carbon_monoxide', 'carbon_dioxide', 'nitrogen_dioxide', 'ammonia', 'methane', 'sulphur_dioxide', 'ozone']
#                         date  pm10  pm2_5  carbon_monoxide  carbon_dioxide  \
# 0  2020-01-01 00:00:00+00:00   NaN    NaN              NaN             NaN
# 1  2020-01-01 01:00:00+00:00   NaN    NaN              NaN             NaN
# 2  2020-01-01 02:00:00+00:00   NaN    NaN              NaN             NaN
# 3  2020-01-01 03:00:00+00:00   NaN    NaN              NaN             NaN
# 4  2020-01-01 04:00:00+00:00   NaN    NaN              NaN             NaN
#
#    nitrogen_dioxide  ammonia  methane  sulphur_dioxide  ozone
# 0               NaN      NaN      NaN              NaN    NaN
# 1               NaN      NaN      NaN              NaN    NaN
# 2               NaN      NaN      NaN              NaN    NaN
# 3               NaN      NaN      NaN              NaN    NaN
# 4               NaN      NaN      NaN              NaN    NaN
#
# Missing per column:
#  date                    0
# pm10                22704
# pm2_5               22704
# carbon_monoxide     22704
# carbon_dioxide      42240
# nitrogen_dioxide    22704
# ammonia             43872
# methane             42240
# sulphur_dioxide     22704
# ozone               22704
# dtype: int64

# %%
df.columns = (
    df.columns.str.strip()
              .str.lower()
              .str.replace(" ", "_", regex=False)
              .str.replace("-", "_", regex=False)
)

print(df.columns.tolist())
# Out:
# ['date', 'pm10', 'pm2_5', 'carbon_monoxide', 'carbon_dioxide', 'nitrogen_dioxide', 'ammonia', 'methane', 'sulphur_dioxide', 'ozone']

# %%
candidates = ["datetime", "date_time", "date", "time", "timestamp"]
dt_col = next((c for c in candidates if c in df.columns), None)

if dt_col is None:
    raise RuntimeError("No datetime column found. Rename your date/time column to one of: " + ", ".join(candidates))

df["datetime"] = pd.to_datetime(df[dt_col], errors="coerce")
print(f"Parsed datetime column: '{dt_col}' — null after parse = {df['datetime'].isna().sum()}")

df = df.dropna(subset=["datetime"]).copy()
df = df.sort_values("datetime").reset_index(drop=True)
print("Rows after datetime cleaning:", len(df))
# Out:
# Parsed datetime column: 'date' — null after parse = 0
# Rows after datetime cleaning: 43872

# %%
pollutants = [
    "pm10","pm2_5","ammonia","carbon_monoxide",
    "nitrogen_dioxide","carbon_dioxide","sulphur_dioxide","methane"
]

# map common variants (pm2.5, pm25, etc.) to pm2_5
col_map = {}
for p in pollutants:
    if p not in df.columns:
        alternatives = [
            p.replace("_",""),
            p.replace("2_5","2.5"),
            p.replace("pm2_5","pm2.5"),
            "pm25","pm2.5"
        ]
        for alt in alternatives:
            if alt in df.columns:
                col_map[alt] = p

if col_map:
    df = df.rename(columns=col_map)
    print("Renamed columns:", col_map)

missing = [p for p in pollutants if p not in df.columns]
if missing:
    print("Warning — missing pollutant columns:", missing)

# convert to numeric and clean strings like "<1" or "1,234"
for p in pollutants:
    if p in df.columns:
        df[p] = (
            df[p].astype(str)
                 .str.replace("<", "", regex=False)
                 .str.replace(",", "", regex=False)
                 .str.strip()
        )
        df[p] = pd.to_numeric(df[p], errors="coerce")

# %%
for p in pollutants:
    if p in df.columns:
        df.loc[df[p] < 0, p] = np.nan

for p in pollutants:
    if p in df.columns:
        q = df[p].quantile(0.999)
        if pd.notna(q) and q > 0:
            df.loc[df[p] > q, p] = np.nan
        print(f"{p}: 99.9% cap = {q}")
# Out:
# pm10: 99.9% cap = 166.7
# pm2_5: 99.9% cap = 116.04970000000212
# ammonia: 99.9% cap = nan
# carbon_monoxide: 99.9% cap = 1340.0
# nitrogen_dioxide: 99.9% cap = 203.19980000000143
# carbon_dioxide: 99.9% cap = 702.0
# sulphur_dioxide: 99.9% cap = 260.21630000000255
# methane: 99.9% cap = 1722.0

# %%
df = df.set_index("datetime")

start = df.index.min().ceil("H")
end   = df.index.max().floor("H")

full_idx = pd.date_range(start=start, end=end, freq="H")

df = df.reindex(full_idx)
print("Reindexed hourly — new length:", len(df))
# Out:
# Reindexed hourly — new length: 43872
# /tmp/ipython-input-2946176890.py:3: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   start = df.index.min().ceil("H")
# /tmp/ipython-input-2946176890.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   end   = df.index.max().floor("H")
# /tmp/ipython-input-2946176890.py:6: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   full_idx = pd.date_range(start=start, end=end, freq="H")

# %%
numeric_cols = [c for c in pollutants if c in df.columns]

df[numeric_cols] = df[numeric_cols].interpolate(method="time", limit=24)
df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

print("Remaining NaNs per pollutant:\n", df[numeric_cols].isna().sum())
# Out:
# Remaining NaNs per pollutant:
#  pm10                22698
# pm2_5               22698
# ammonia             43872
# carbon_monoxide     22698
# nitrogen_dioxide    22698
# carbon_dioxide      42234
# sulphur_dioxide     22698
# methane             42234
# dtype: int64
# /tmp/ipython-input-1757015156.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[numeric_cols] = df[numeric_cols].fillna(method="ffill", limit=6).fillna(method="bfill", limit=6)

# %%
df["n_missing_pollutants"] = df[numeric_cols].isna().sum(axis=1)
summary = df[numeric_cols].describe().T
summary["missing_count"] = df[numeric_cols].isna().sum()
summary
# Out:
#                     count         mean         std     min     25%     50%  \
# pm10              21174.0    36.083943   25.645301     0.6    18.2    29.0
# pm2_5             21174.0    24.434273   18.059472     0.4    11.8    19.2
# ammonia               0.0          NaN         NaN     NaN     NaN     NaN
# carbon_monoxide   21174.0   327.112851  175.360840    59.0   212.0   278.0
# nitrogen_dioxide  21174.0    53.102596   27.887931     0.0    31.7    50.9
# carbon_dioxide     1638.0   495.726496   45.326033   440.0   462.0   482.0
# sulphur_dioxide   21174.0    31.758095   32.945841     0.0    10.3    22.0
# methane            1638.0  1473.307082   68.043370  1363.0  1420.0  1460.0
#
#                         75%     max  missing_count
# pm10                46.3000   166.7          22698
# pm2_5               31.3000   115.3          22698
# ammonia                 NaN     NaN          43872
# carbon_monoxide    390.0000  1340.0          22698
# nitrogen_dioxide    69.9375   202.7          22698
# carbon_dioxide     518.0000   702.0          42234
# sulphur_dioxide     41.6000   259.3          22698
# methane           1516.7500  1722.0          42234

# %%
means = df[numeric_cols].mean(skipna=True)
ranking = means.reset_index()
ranking.columns = ["pollutant", "mean_value"]

# separate valid and invalid means
valid = ranking[ranking["mean_value"].notna()].copy()
invalid = ranking[ranking["mean_value"].isna()].copy()

valid["rank"] = valid["mean_value"].rank(method="min", ascending=False).astype(int)
invalid["rank"] = pd.NA

final_ranking = pd.concat([valid, invalid], ignore_index=True)
final_ranking = final_ranking.sort_values(["rank","pollutant"], na_position="last").reset_index(drop=True)

print(final_ranking)

# Save cleaned hourly and ranking
df.reset_index().rename(columns={"index":"datetime"}).to_csv("Tokyo_clean_hourly.csv", index=False)
final_ranking.to_csv("Tokyo_pollutant_ranking.csv", index=False)

print("Saved: Tokyo_clean_hourly.csv and Tokyo_pollutant_ranking.csv")
# Out:
#           pollutant   mean_value  rank
# 0           methane  1473.307082     1
# 1    carbon_dioxide   495.726496     2
# 2   carbon_monoxide   327.112851     3
# 3  nitrogen_dioxide    53.102596     4
# 4              pm10    36.083943     5
# 5   sulphur_dioxide    31.758095     6
# 6             pm2_5    24.434273     7
# 7           ammonia          NaN  <NA>
# Saved: Tokyo_clean_hourly.csv and Tokyo_pollutant_ranking.csv

# %% [markdown]
# CLUSTERING PROCESS (HIERARCHICAL CLUSTERING)

# %%
import pandas as pd

# Load each city’s pollutant mean file
bei = pd.read_csv("Beijing_pollutant_ranking.csv")
dlh = pd.read_csv("Delhi_pollutant_ranking.csv")
dha = pd.read_csv("Dhaka_pollutant_ranking.csv")
sha = pd.read_csv("Shanghai_pollutant_ranking.csv")
tok = pd.read_csv("Tokyo_pollutant_ranking.csv")

# Add city names
bei["city"] = "Beijing"
dlh["city"] = "Delhi"
dha["city"] = "Dhaka"
sha["city"] = "Shanghai"
tok["city"] = "Tokyo"

# Combine into one table
df_means = pd.concat([bei, dlh, dha, sha,  tok], ignore_index=True)

df_means
# Out:
#            pollutant   mean_value  rank      city
# 0            methane  2379.612332   1.0   Beijing
# 1    carbon_monoxide  1302.999126   2.0   Beijing
# 2     carbon_dioxide   528.908425   3.0   Beijing
# 3               pm10   108.341138   4.0   Beijing
# 4              pm2_5    75.294366   5.0   Beijing
# 5    sulphur_dioxide    66.882944   6.0   Beijing
# 6   nitrogen_dioxide    62.544712   7.0   Beijing
# 7            ammonia          NaN   NaN   Beijing
# 8            methane  1653.462149   1.0     Delhi
# 9    carbon_monoxide  1069.667564   2.0     Delhi
# 10    carbon_dioxide   473.523810   3.0     Delhi
# 11              pm10   118.459887   4.0     Delhi
# 12             pm2_5    68.909240   5.0     Delhi
# 13  nitrogen_dioxide    46.020609   6.0     Delhi
# 14   sulphur_dioxide    41.151593   7.0     Delhi
# 15           ammonia          NaN   NaN     Delhi
# 16           methane  2353.919414   1.0     Dhaka
# 17   carbon_monoxide   619.268726   2.0     Dhaka
# 18    carbon_dioxide   466.781441   3.0     Dhaka
# 19              pm10    70.797823   4.0     Dhaka
# 20             pm2_5    48.976398   5.0     Dhaka
# 21  nitrogen_dioxide    36.492148   6.0     Dhaka
# 22   sulphur_dioxide    12.906757   7.0     Dhaka
# 23           ammonia          NaN   NaN     Dhaka
# 24           methane  1734.468254   1.0  Shanghai
# 25   carbon_monoxide  1055.324785   2.0  Shanghai
# 26    carbon_dioxide   512.164835   3.0  Shanghai
# 27              pm10    69.138963   4.0  Shanghai
# 28  nitrogen_dioxide    63.593974   5.0  Shanghai
# 29   sulphur_dioxide    60.725479   6.0  Shanghai
# 30             pm2_5    46.537692   7.0  Shanghai
# 31           ammonia          NaN   NaN  Shanghai
# 32           methane  1473.307082   1.0     Tokyo
# 33    carbon_dioxide   495.726496   2.0     Tokyo
# 34   carbon_monoxide   327.112851   3.0     Tokyo
# 35  nitrogen_dioxide    53.102596   4.0     Tokyo
# 36              pm10    36.083943   5.0     Tokyo
# 37   sulphur_dioxide    31.758095   6.0     Tokyo
# 38             pm2_5    24.434273   7.0     Tokyo
# 39           ammonia          NaN   NaN     Tokyo

# %%
df_city = df_means.pivot(index="city", columns="pollutant", values="mean_value")

df_city
# Out:
# pollutant  ammonia  carbon_dioxide  carbon_monoxide      methane  \
# city
# Beijing        NaN      528.908425      1302.999126  2379.612332
# Delhi          NaN      473.523810      1069.667564  1653.462149
# Dhaka          NaN      466.781441       619.268726  2353.919414
# Shanghai       NaN      512.164835      1055.324785  1734.468254
# Tokyo          NaN      495.726496       327.112851  1473.307082
#
# pollutant  nitrogen_dioxide        pm10      pm2_5  sulphur_dioxide
# city
# Beijing           62.544712  108.341138  75.294366        66.882944
# Delhi             46.020609  118.459887  68.909240        41.151593
# Dhaka             36.492148   70.797823  48.976398        12.906757
# Shanghai          63.593974   69.138963  46.537692        60.725479
# Tokyo             53.102596   36.083943  24.434273        31.758095

# %%
import numpy as np
import pandas as pd

try:
    df_city
except NameError:
    # replace filename if needed
    df_city = pd.read_csv("df_city.csv", index_col=0)

print("Original df_city:\n")
display(df_city)

# Replace inf with NaN
df_city = df_city.replace([np.inf, -np.inf], np.nan)

# Show NaN summary
print("\nNaN per column before cleaning:")
print(df_city.isna().sum())

# Drop columns that are entirely NaN (like ammonia)
all_nan_cols = df_city.columns[df_city.isna().all()].tolist()
if all_nan_cols:
    print("\nDropping columns with all NaN:", all_nan_cols)
    df_city = df_city.drop(columns=all_nan_cols)

# If any columns have many NaNs (>80%) drop them:
too_many = df_city.columns[df_city.isna().mean() > 0.8].tolist()
if too_many:
    print("Dropping columns with >80% NaN:", too_many)
    df_city = df_city.drop(columns=too_many)

# Impute remaining NaNs with column median (safe for small table)
if df_city.isna().any().any():
    print("Imputing remaining NaNs with column median.")
    df_city = df_city.fillna(df_city.median())

print("\nPost-cleaning df_city:")
display(df_city)
# Out:
# Original df_city:
# pollutant  ammonia  carbon_dioxide  carbon_monoxide      methane  \
# city
# Beijing        NaN      528.908425      1302.999126  2379.612332
# Delhi          NaN      473.523810      1069.667564  1653.462149
# Dhaka          NaN      466.781441       619.268726  2353.919414
# Shanghai       NaN      512.164835      1055.324785  1734.468254
# Tokyo          NaN      495.726496       327.112851  1473.307082
#
# pollutant  nitrogen_dioxide        pm10      pm2_5  sulphur_dioxide
# city
# Beijing           62.544712  108.341138  75.294366        66.882944
# Delhi             46.020609  118.459887  68.909240        41.151593
# Dhaka             36.492148   70.797823  48.976398        12.906757
# Shanghai          63.593974   69.138963  46.537692        60.725479
# Tokyo             53.102596   36.083943  24.434273        31.758095
# NaN per column before cleaning:
# pollutant
# ammonia             5
# carbon_dioxide      0
# carbon_monoxide     0
# methane             0
# nitrogen_dioxide    0
# pm10                0
# pm2_5               0
# sulphur_dioxide     0
# dtype: int64
#
# Dropping columns with all NaN: ['ammonia']
#
# Post-cleaning df_city:
# pollutant  carbon_dioxide  carbon_monoxide      methane  nitrogen_dioxide  \
# city
# Beijing        528.908425      1302.999126  2379.612332         62.544712
# Delhi          473.523810      1069.667564  1653.462149         46.020609
# Dhaka          466.781441       619.268726  2353.919414         36.492148
# Shanghai       512.164835      1055.324785  1734.468254         63.593974
# Tokyo          495.726496       327.112851  1473.307082         53.102596
#
# pollutant        pm10      pm2_5  sulphur_dioxide
# city
# Beijing    108.341138  75.294366        66.882944
# Delhi      118.459887  68.909240        41.151593
# Dhaka       70.797823  48.976398        12.906757
# Shanghai    69.138963  46.537692        60.725479
# Tokyo       36.083943  24.434273        31.758095

# %%
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
import matplotlib.pyplot as plt

# convert to float matrix
X = df_city.values.astype(float)

# Standardize
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# linkage
Z = linkage(X_scaled, method="ward")

# plot dendrogram
plt.figure(figsize=(6,4))
dendrogram(Z, labels=df_city.index.tolist(), leaf_rotation=0, leaf_font_size=12)
plt.title("Hierarchical clustering (Ward) — Asian cities")
plt.ylabel("Linkage distance")
plt.tight_layout()
plt.show()

# assign cluster labels (choose k, e.g., 2)
k = 2
labels = fcluster(Z, t=k, criterion="maxclust")
df_city["cluster"] = labels
print("\nAssigned clusters:")
display(df_city[["cluster"]])
# Out:
# Assigned clusters:
# pollutant  cluster
# city
# Beijing          1
# Delhi            2
# Dhaka            2
# Shanghai         1
# Tokyo            2

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(9, 6)) # Increased figure size for better label visibility
# use standardized values for heatmap to show relative differences
X_scaled_df = pd.DataFrame(X_scaled, index=df_city.index, columns=df_city.columns[:-1] if "cluster" in df_city.columns else df_city.columns)
sns.heatmap(X_scaled_df, annot=True, fmt=".2f", cmap="vlag", cbar_kws={"label": "z-score"})
plt.title("Standardized pollutant means (Asian cities)")
plt.ylabel("City")
plt.xlabel("Pollutant")
plt.yticks(rotation=0) # Rotate city names to be horizontal
plt.tight_layout()
plt.show()
